# %%
import json

# %%
with open(r'raw-data\Discourse-data\topic_161071.json', 'r') as file:
    data = json.load(file)

# %%
data
# Out:
# {'post_stream': {'posts': [{'id': 575209,
#     'name': 'Tanya kamboj',
#     'username': '21f3000745',
#     'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/21f3000745/{size}/638_2.png',
#     'created_at': '2025-01-01T16:04:48.996Z',
#     'cooked': '<p>Hii allâ€¦i know this may not be the correct platform to ask this question.<br>\nActually i have 3 diploma subjects to cover - MLP, JAVA, TDS. So which 2 subject should i choose for this term?</p>',
#     'post_number': 1,
#     'post_type': 1,
#     'posts_count': 4,
#     'updated_at': '2025-01-01T16:04:48.996Z',
#     'reply_count': 0,
#     'reply_to_post_number': None,
#     'quote_count': 0,
#     'incoming_link_count': 0,
#     'reads': 80,
#     'readers_count': 79,
#     'score': 15.0,
#     'yours': False,
#     'topic_id': 161071,
#     'topic_slug': 'which-subject-to-choose-in-jan-term',
#     'display_username': 'Tanya kamboj',
#     'primary_group_name': 'ds-students',
#     'flair_name': 'ds-students',
#     'flair_url': None,
#     'flair_bg_color': '',
#     'flair_color': '',
#     'flair_group_id': 294,
#     'badges_granted': [],
#     'version': 1,
#     'can_edit': False,
#     'can_delete': False,
#     'can_recover': False,
#     'can_see_hidden_post': False,
#     'can_wiki': False,
#     'read': False,
#     'user_title': None,
#     'bookmarked': False,
#     'actions_summary': [{'id': 2, 'can_act': True},
#      {'id': 6, 'can_act': True},
#      {'id': 3, 'can_act': True},
#      {'id': 4, 'can_act': True},
#      {'id': 8, 'can_act': True},
#      {'id': 10, 'can_act': True},
#      {'id': 7, 'can_act': True}],
#     'moderator': False,
#     'admin': False,
#     'staff': False,
#     'user_id': 7742,
#     'hidden': False,
#     'trust_level': 1,
#     'deleted_at': None,
#     'user_deleted': False,
#     'edit_reason': None,
#     'can_view_edit_history': True,
#     'wiki': False,
#     'post_url': '/t/which-subject-to-choose-in-jan-term/161071/1',
#     'user_cakedate': '2021-10-08',
#     'reactions': [],
#     'current_user_reaction': None,
#     'reaction_users_count': 0,
#     'current_user_used_main_reaction': False,
#     'can_accept_answer': False,
#     'can_unaccept_answer': False,
#     'accepted_answer': False,
#     'topic_accepted_answer': None,
#     'can_vote': False},
#    {'id': 575247,
#     'name': 'Rajat Goel',
#     'username': '22f3002293',
#     'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/22f3002293/{size}/92210_2.png',
#     'created_at': '2025-01-01T16:49:57.552Z',
#     'cooked': '<p>Donâ€™t take TDS, this subject should be taken in the end else you might have some problem</p>',
#     'post_number': 2,
#     'post_type': 1,
#     'posts_count': 4,
#     'updated_at': '2025-01-01T16:49:57.552Z',
#     'reply_count': 0,
#     'reply_to_post_number': None,
#     'quote_count': 0,
#     'incoming_link_count': 0,
#     'reads': 79,
#     'readers_count': 78,
#     'score': 14.8,
#     'yours': False,
#     'topic_id': 161071,
#     'topic_slug': 'which-subject-to-choose-in-jan-term',
#     'display_username': 'Rajat Goel',
#     'primary_group_name': 'ds-students',
#     'flair_name': 'ds-students',
#     'flair_url': None,
#     'flair_bg_color': '',
#     'flair_color': '',
#     'flair_group_id': 294,
#     'badges_granted': [],
#     'version': 1,
#     'can_edit': False,
#     'can_delete': False,
#     'can_recover': False,
#     'can_see_hidden_post': False,
#     'can_wiki': False,
#     'read': False,
#     'user_title': '',
#     'bookmarked': False,
#     'actions_summary': [{'id': 2, 'can_act': True},
#      {'id': 6, 'can_act': True},
#      {'id': 3, 'can_act': True},
#      {'id': 4, 'can_act': True},
#      {'id': 8, 'can_act': True},
#      {'id': 10, 'can_act': True},
#      {'id': 7, 'can_act': True}],
#     'moderator': False,
#     'admin': False,
#     'staff': False,
#     'user_id': 15475,
#     'hidden': False,
#     'trust_level': 2,
#     'deleted_at': None,
#     'user_deleted': False,
#     'edit_reason': None,
#     'can_view_edit_history': True,
#     'wiki': False,
#     'post_url': '/t/which-subject-to-choose-in-jan-term/161071/2',
#     'user_cakedate': '2023-01-23',
#     'user_birthdate': '1904-05-17',
#     'reactions': [],
#     'current_user_reaction': None,
#     'reaction_users_count': 0,
#     'current_user_used_main_reaction': False,
#     'can_accept_answer': False,
#     'can_unaccept_answer': False,
#     'accepted_answer': False,
#     'topic_accepted_answer': None},
#    {'id': 575349,
#     'name': "Carlton D'Silva",
#     'username': 'carlton',
#     'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/carlton/{size}/56317_2.png',
#     'created_at': '2025-01-02T03:23:20.202Z',
#     'cooked': '<p>TDS at the end best. Gives you the best chance of doing well in it.</p>\n<p>Kind regards</p>',
#     'post_number': 3,
#     'post_type': 1,
#     'posts_count': 4,
#     'updated_at': '2025-01-02T03:23:20.202Z',
#     'reply_count': 0,
#     'reply_to_post_number': None,
#     'quote_count': 0,
#     'incoming_link_count': 0,
#     'reads': 74,
#     'readers_count': 73,
#     'score': 14.0,
#     'yours': False,
#     'topic_id': 161071,
#     'topic_slug': 'which-subject-to-choose-in-jan-term',
#     'display_username': "Carlton D'Silva",
#     'primary_group_name': 'ds-students',
#     'flair_name': 'ds-students',
#     'flair_url': None,
#     'flair_bg_color': '',
#     'flair_color': '',
#     'flair_group_id': 294,
#     'badges_granted': [],
#     'version': 1,
#     'can_edit': False,
#     'can_delete': False,
#     'can_recover': False,
#     'can_see_hidden_post': False,
#     'can_wiki': False,
#     'read': False,
#     'user_title': 'Regular',
#     'title_is_group': False,
#     'bookmarked': False,
#     'actions_summary': [{'id': 2, 'can_act': True},
#      {'id': 6, 'can_act': True},
#      {'id': 3, 'can_act': True},
#      {'id': 4, 'can_act': True},
#      {'id': 8, 'can_act': True},
#      {'id': 10, 'can_act': True},
#      {'id': 7, 'can_act': True}],
#     'moderator': False,
#     'admin': False,
#     'staff': False,
#     'group_moderator': True,
#     'user_id': 16094,
#     'hidden': False,
#     'trust_level': 3,
#     'deleted_at': None,
#     'user_deleted': False,
#     'edit_reason': None,
#     'can_view_edit_history': True,
#     'wiki': False,
#     'post_url': '/t/which-subject-to-choose-in-jan-term/161071/3',
#     'user_cakedate': '2023-01-25',
#     'reactions': [],
#     'current_user_reaction': None,
#     'reaction_users_count': 0,
#     'current_user_used_main_reaction': False,
#     'can_accept_answer': False,
#     'can_unaccept_answer': False,
#     'accepted_answer': False,
#     'topic_accepted_answer': None},
#    {'id': 576005,
#     'name': 'Aditya choudhary',
#     'username': 'Adityach1',
#     'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/adityach1/{size}/67114_2.png',
#     'created_at': '2025-01-06T14:17:03.518Z',
#     'cooked': '<p>Yes you should do tds after mlp only it really help you alot trust me</p>',
#     'post_number': 4,
#     'post_type': 1,
#     'posts_count': 4,
#     'updated_at': '2025-01-06T14:17:03.518Z',
#     'reply_count': 0,
#     'reply_to_post_number': None,
#     'quote_count': 0,
#     'incoming_link_count': 0,
#     'reads': 42,
#     'readers_count': 41,
#     'score': 7.6,
#     'yours': False,
#     'topic_id': 161071,
#     'topic_slug': 'which-subject-to-choose-in-jan-term',
#     'display_username': 'Aditya choudhary',
#     'primary_group_name': 'ds-students',
#     'flair_name': 'ds-students',
#     'flair_url': None,
#     'flair_bg_color': '',
#     'flair_color': '',
#     'flair_group_id': 294,
#     'badges_granted': [],
#     'version': 1,
#     'can_edit': False,
#     'can_delete': False,
#     'can_recover': False,
#     'can_see_hidden_post': False,
#     'can_wiki': False,
#     'read': False,
#     'user_title': '',
#     'bookmarked': False,
#     'actions_summary': [{'id': 2, 'can_act': True},
#      {'id': 6, 'can_act': True},
#      {'id': 3, 'can_act': True},
#      {'id': 4, 'can_act': True},
#      {'id': 8, 'can_act': True},
#      {'id': 10, 'can_act': True},
#      {'id': 7, 'can_act': True}],
#     'moderator': False,
#     'admin': False,
#     'staff': False,
#     'user_id': 4387,
#     'hidden': False,
#     'trust_level': 1,
#     'deleted_at': None,
#     'user_deleted': False,
#     'edit_reason': None,
#     'can_view_edit_history': True,
#     'wiki': False,
#     'post_url': '/t/which-subject-to-choose-in-jan-term/161071/4',
#     'user_cakedate': '2021-05-06',
#     'reactions': [],
#     'current_user_reaction': None,
#     'reaction_users_count': 0,
#     'current_user_used_main_reaction': False,
#     'can_accept_answer': False,
#     'can_unaccept_answer': False,
#     'accepted_answer': False,
#     'topic_accepted_answer': None}],
#   'stream': [575209, 575247, 575349, 576005]},
#  'timeline_lookup': [[1, 150], [4, 145]],
#  'suggested_topics': [{'id': 173524,
#    'title': 'GA1 - Development Tools - Discussion Thread [TDS May 2025]',
#    'fancy_title': 'GA1 - Development Tools - Discussion Thread [TDS May 2025]',
#    'slug': 'ga1-development-tools-discussion-thread-tds-may-2025',
#    'posts_count': 80,
#    'reply_count': 51,
#    'highest_post_number': 85,
#    'image_url': None,
#    'created_at': '2025-05-01T11:39:00.734Z',
#    'last_posted_at': '2025-05-31T15:34:18.368Z',
#    'bumped': True,
#    'bumped_at': '2025-05-31T15:34:18.368Z',
#    'archetype': 'regular',
#    'unseen': False,
#    'last_read_post_number': 82,
#    'unread': 0,
#    'new_posts': 3,
#    'unread_posts': 3,
#    'pinned': False,
#    'unpinned': None,
#    'visible': True,
#    'closed': False,
#    'archived': False,
#    'notification_level': 2,
#    'bookmarked': False,
#    'liked': False,
#    'tags': ['term2-2025', 'graded-assignment'],
#    'tags_descriptions': {},
#    'like_count': 25,
#    'views': 1155,
#    'category_id': 34,
#    'featured_link': None,
#    'has_accepted_answer': False,
#    'posters': [{'extras': None,
#      'description': 'Original Poster',
#      'user': {'id': 9419,
#       'username': 's.anand',
#       'name': 'Anand S',
#       'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/s.anand/{size}/15264_2.png',
#       'primary_group_name': 'faculty',
#       'flair_name': 'faculty',
#       'flair_url': 'chalkboard-user',
#       'flair_bg_color': 'f2c26e',
#       'flair_color': '000',
#       'flair_group_id': 54,
#       'trust_level': 4}},
#     {'extras': None,
#      'description': 'Frequent Poster',
#      'user': {'id': 22472,
#       'username': 'Advaith52',
#       'name': 'Advaith Sanil Kumar',
#       'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/advaith52/{size}/67172_2.png',
#       'primary_group_name': 'ds-students',
#       'flair_name': 'ds-students',
#       'flair_group_id': 294,
#       'trust_level': 1}},
#     {'extras': None,
#      'description': 'Frequent Poster',
#      'user': {'id': 16094,
#       'username': 'carlton',
#       'name': "Carlton D'Silva",
#       'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/carlton/{size}/56317_2.png',
#       'primary_group_name': 'ds-students',
#       'flair_name': 'ds-students',
#       'flair_group_id': 294,
#       'trust_level': 3}},
#     {'extras': None,
#      'description': 'Frequent Poster',
#      'user': {'id': 15658,
#       'username': 'HritikRoshan_HRM',
#       'name': 'HRITIK ROSHAN MAURYA',
#       'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/hritikroshan_hrm/{size}/66975_2.png',
#       'primary_group_name': 'ds-students',
#       'flair_name': 'ds-students',
#       'flair_group_id': 294,
#       'trust_level': 1}},
#     {'extras': 'latest',
#      'description': 'Most Recent Poster',
#      'user': {'id': 12914,
#       'username': 'iAnimeshS',
#       'name': 'Animesh',
#       'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/ianimeshs/{size}/12415_2.png',
#       'primary_group_name': 'ds-students',
#       'flair_name': 'ds-students',
#       'flair_group_id': 294,
#       'trust_level': 1}}]},
#   {'id': 176789,
#    'title': 'Vercel deployement error',
#    'fancy_title': 'Vercel deployement error',
#    'slug': 'vercel-deployement-error',
#    'posts_count': 1,
#    'reply_count': 0,
#    'highest_post_number': 1,
#    'image_url': None,
#    'created_at': '2025-05-31T11:55:22.507Z',
#    'last_posted_at': '2025-05-31T11:55:22.708Z',
#    'bumped': True,
#    'bumped_at': '2025-05-31T11:55:22.708Z',
#    'archetype': 'regular',
#    'unseen': True,
#    'pinned': False,
#    'unpinned': None,
#    'visible': True,
#    'closed': False,
#    'archived': False,
#    'bookmarked': None,
#    'liked': None,
#    'tags': ['diploma-level', 'term2-2025'],
#    'tags_descriptions': {},
#    'like_count': 0,
#    'views': 9,
#    'category_id': 34,
#    'featured_link': None,
#    'has_accepted_answer': False,
#    'posters': [{'extras': 'latest single',
#      'description': 'Original Poster, Most Recent Poster',
#      'user': {'id': 25506,
#       'username': '23f3003724',
#       'name': 'Vedika Gupta',
#       'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/23f3003724/{size}/68806_2.png',
#       'primary_group_name': 'ds-students',
#       'flair_name': 'ds-students',
#       'flair_group_id': 294,
#       'trust_level': 1}}]}],
#  'tags': ['clarification', 'miscellaneous'],
#  'tags_descriptions': {},
#  'id': 161071,
#  'title': 'Which subject to choose in jan term',
#  'fancy_title': 'Which subject to choose in jan term',
#  'posts_count': 4,
#  'created_at': '2025-01-01T16:04:48.718Z',
#  'views': 99,
#  'reply_count': 0,
#  'like_count': 0,
#  'last_posted_at': '2025-01-06T14:17:03.518Z',
#  'visible': True,
#  'closed': False,
#  'archived': False,
#  'has_summary': False,
#  'archetype': 'regular',
#  'slug': 'which-subject-to-choose-in-jan-term',
#  'category_id': 34,
#  'word_count': 86,
#  'deleted_at': None,
#  'user_id': 7742,
#  'featured_link': None,
#  'pinned_globally': False,
#  'pinned_at': None,
#  'pinned_until': None,
#  'image_url': None,
#  'slow_mode_seconds': 0,
#  'draft': None,
#  'draft_key': 'topic_161071',
#  'draft_sequence': 0,
#  'unpinned': None,
#  'pinned': False,
#  'current_post_number': 1,
#  'highest_post_number': 4,
#  'deleted_by': None,
#  'actions_summary': [{'id': 4, 'count': 0, 'hidden': False, 'can_act': True},
#   {'id': 8, 'count': 0, 'hidden': False, 'can_act': True},
#   {'id': 10, 'count': 0, 'hidden': False, 'can_act': True},
#   {'id': 7, 'count': 0, 'hidden': False, 'can_act': True}],
#  'chunk_size': 20,
#  'bookmarked': False,
#  'topic_timer': None,
#  'message_bus_last_id': 0,
#  'participant_count': 4,
#  'show_read_indicator': False,
#  'thumbnails': None,
#  'slow_mode_enabled_until': None,
#  'tags_disable_ads': False,
#  'related_topics': [{'id': 57018,
#    'title': 'Subject selection plan',
#    'fancy_title': 'Subject selection plan',
#    'slug': 'subject-selection-plan',
#    'posts_count': 2,
#    'reply_count': 0,
#    'highest_post_number': 2,
#    'image_url': None,
#    'created_at': '2022-07-09T03:12:10.412Z',
#    'last_posted_at': '2022-07-09T05:36:49.979Z',
#    'bumped': True,
#    'bumped_at': '2022-07-09T05:36:49.979Z',
#    'archetype': 'regular',
#    'unseen': False,
#    'pinned': False,
#    'unpinned': None,
#    'visible': True,
#    'closed': False,
#    'archived': False,
#    'bookmarked': None,
#    'liked': None,
#    'tags': ['clarification'],
#    'tags_descriptions': {},
#    'like_count': 0,
#    'views': 55,
#    'category_id': 32,
#    'featured_link': None,
#    'has_accepted_answer': False,
#    'posters': [{'extras': None,
#      'description': 'Original Poster',
#      'user': {'id': 5130,
#       'username': 'RajanDas',
#       'name': 'Rajan Das',
#       'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/rajandas/{size}/591_2.png',
#       'primary_group_name': 'ds-students',
#       'flair_name': 'ds-students',
#       'flair_group_id': 294,
#       'trust_level': 1}},
#     {'extras': 'latest',
#      'description': 'Most Recent Poster',
#      'user': {'id': 1142,
#       'username': 'Harususan',
#       'name': 'Harsh Bhat',
#       'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/harususan/{size}/1315_2.png',
#       'primary_group_name': 'ds-students',
#       'flair_name': 'ds-students',
#       'flair_group_id': 294,
#       'trust_level': 1}}]},
#   {'id': 172849,
#    'title': 'Subject choosing help',
#    'fancy_title': 'Subject choosing help',
#    'slug': 'subject-choosing-help',
#    'posts_count': 3,
#    'reply_count': 0,
#    'highest_post_number': 3,
#    'image_url': None,
#    'created_at': '2025-04-17T01:59:10.917Z',
#    'last_posted_at': '2025-05-09T07:24:25.261Z',
#    'bumped': True,
#    'bumped_at': '2025-05-09T07:24:25.261Z',
#    'archetype': 'regular',
#    'unseen': False,
#    'pinned': False,
#    'unpinned': None,
#    'visible': True,
#    'closed': False,
#    'archived': False,
#    'bookmarked': None,
#    'liked': None,
#    'tags': ['course-selection'],
#    'tags_descriptions': {},
#    'like_count': 0,
#    'views': 88,
#    'category_id': 75,
#    'featured_link': None,
#    'has_accepted_answer': False,
#    'posters': [{'extras': 'latest',
#      'description': 'Original Poster, Most Recent Poster',
#      'user': {'id': 30937,
#       'username': 'Sobia',
#       'name': 'Sobiya qayoom',
#       'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/sobia/{size}/66760_2.png',
#       'primary_group_name': 'ds-students',
#       'flair_name': 'ds-students',
#       'flair_group_id': 294,
#       'trust_level': 1}},
#     {'extras': None,
#      'description': 'Frequent Poster',
#      'user': {'id': 17612,
#       'username': 'ankitx9',
#       'name': 'Ankit ',
#       'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/ankitx9/{size}/77720_2.png',
#       'primary_group_name': 'ds-students',
#       'flair_name': 'ds-students',
#       'flair_group_id': 294,
#       'trust_level': 1}}]},
#   {'id': 44291,
#    'title': 'What should I take next?',
#    'fancy_title': 'What should I take next?',
#    'slug': 'what-should-i-take-next',
#    'posts_count': 47,
#    'reply_count': 36,
#    'highest_post_number': 47,
#    'image_url': None,
#    'created_at': '2022-04-06T16:14:56.089Z',
#    'last_posted_at': '2022-12-21T17:14:14.688Z',
#    'bumped': True,
#    'bumped_at': '2022-12-21T17:14:14.688Z',
#    'archetype': 'regular',
#    'unseen': False,
#    'pinned': False,
#    'unpinned': None,
#    'visible': True,
#    'closed': False,
#    'archived': False,
#    'bookmarked': None,
#    'liked': None,
#    'tags': ['course-selection'],
#    'tags_descriptions': {},
#    'like_count': 24,
#    'views': 1222,
#    'category_id': 44,
#    'featured_link': None,
#    'has_accepted_answer': False,
#    'posters': [{'extras': None,
#      'description': 'Original Poster',
#      'user': {'id': 6489,
#       'username': 'NGV',
#       'name': 'Nikhil Guru Venkatesh ',
#       'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/ngv/{size}/8597_2.png',
#       'primary_group_name': 'ds-students',
#       'flair_name': 'ds-students',
#       'flair_group_id': 294,
#       'trust_level': 1}},
#     {'extras': None,
#      'description': 'Frequent Poster',
#      'user': {'id': 933,
#       'username': 'Anand',
#       'name': 'Anand Iyer',
#       'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/anand/{size}/1555_2.png',
#       'primary_group_name': 'ds-students',
#       'flair_name': 'ds-students',
#       'flair_group_id': 294,
#       'trust_level': 2}},
#     {'extras': None,
#      'description': 'Frequent Poster',
#      'user': {'id': 3024,
#       'username': 'papadelta_5636',
#       'name': 'Preetodeep Dev',
#       'avatar_template': 'https://avatars.discourse-cdn.com/v4/letter/p/dc4da7/{size}.png',
#       'primary_group_name': 'ds-students',
#       'flair_name': 'Community-TA',
#       'flair_url': 'handshake-angle',
#       'flair_bg_color': '717BF7',
#       'flair_color': '6BEE3D',
#       'flair_group_id': 89,
#       'trust_level': 2}},
#     {'extras': None,
#      'description': 'Frequent Poster',
#      'user': {'id': 3892,
#       'username': 'Horus',
#       'name': 'Arko_Das',
#       'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/horus/{size}/867_2.png',
#       'primary_group_name': 'ds-students',
#       'flair_name': 'ds-students',
#       'flair_group_id': 294,
#       'trust_level': 1}},
#     {'extras': 'latest',
#      'description': 'Most Recent Poster',
#      'user': {'id': 12697,
#       'username': 'shilpabrigit',
#       'name': 'Shilpa Paul',
#       'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/shilpabrigit/{size}/13359_2.png',
#       'primary_group_name': 'ds-students',
#       'flair_name': 'ds-students',
#       'flair_group_id': 294,
#       'trust_level': 1}}]},
#   {'id': 173472,
#    'title': 'Clarification in choosing subject',
#    'fancy_title': 'Clarification in choosing subject',
#    'slug': 'clarification-in-choosing-subject',
#    'posts_count': 2,
#    'reply_count': 0,
#    'highest_post_number': 2,
#    'image_url': None,
#    'created_at': '2025-04-29T09:58:44.850Z',
#    'last_posted_at': '2025-04-29T10:44:54.952Z',
#    'bumped': True,
#    'bumped_at': '2025-04-29T10:44:54.952Z',
#    'archetype': 'regular',
#    'unseen': False,
#    'pinned': False,
#    'unpinned': None,
#    'visible': True,
#    'closed': False,
#    'archived': False,
#    'bookmarked': None,
#    'liked': None,
#    'tags': ['term2-2025', 'term1-2025'],
#    'tags_descriptions': {},
#    'like_count': 1,
#    'views': 50,
#    'category_id': 29,
#    'featured_link': None,
#    'has_accepted_answer': False,
#    'posters': [{'extras': None,
#      'description': 'Original Poster',
#      'user': {'id': 17759,
#       'username': '23f1001823',
#       'name': 'SHOBHIT SHARMA',
#       'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/23f1001823/{size}/66937_2.png',
#       'primary_group_name': 'ds-students',
#       'flair_name': 'ds-students',
#       'flair_group_id': 294,
#       'trust_level': 1}},
#     {'extras': 'latest',
#      'description': 'Most Recent Poster',
#      'user': {'id': 16094,
#       'username': 'carlton',
#       'name': "Carlton D'Silva",
#       'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/carlton/{size}/56317_2.png',
#       'primary_group_name': 'ds-students',
#       'flair_name': 'ds-students',
#       'flair_group_id': 294,
#       'trust_level': 3}}]},
#   {'id': 61307,
#    'title': 'For those that are done with MLT, MLP, TDS',
#    'fancy_title': 'For those that are done with MLT, MLP, TDS',
#    'slug': 'for-those-that-are-done-with-mlt-mlp-tds',
#    'posts_count': 1,
#    'reply_count': 0,
#    'highest_post_number': 1,
#    'image_url': None,
#    'created_at': '2022-08-18T04:57:00.738Z',
#    'last_posted_at': '2022-08-18T04:57:00.838Z',
#    'bumped': True,
#    'bumped_at': '2022-08-18T04:57:00.838Z',
#    'archetype': 'regular',
#    'unseen': False,
#    'pinned': False,
#    'unpinned': None,
#    'visible': True,
#    'closed': False,
#    'archived': False,
#    'bookmarked': None,
#    'liked': None,
#    'tags': [],
#    'tags_descriptions': {},
#    'like_count': 0,
#    'views': 115,
#    'category_id': 44,
#    'featured_link': None,
#    'has_accepted_answer': False,
#    'posters': [{'extras': 'latest single',
#      'description': 'Original Poster, Most Recent Poster',
#      'user': {'id': 1212,
#       'username': 'vishalreddyp',
#       'name': 'Vishal Reddy Parvatha Reddy',
#       'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/vishalreddyp/{size}/19271_2.png',
#       'primary_group_name': 'ds-students',
#       'flair_name': 'ds-students',
#       'flair_group_id': 294,
#       'trust_level': 1}}]}],
#  'summarizable': False,
#  'valid_reactions': ['heart',
#   '+1',
#   'laughing',
#   'open_mouth',
#   'clap',
#   'confetti_ball',
#   'rocket',
#   '-1'],
#  'can_vote': False,
#  'vote_count': 0,
#  'user_voted': False,
#  'discourse_zendesk_plugin_zendesk_id': None,
#  'discourse_zendesk_plugin_zendesk_url': 'https://your-url.zendesk.com/agent/tickets/',
#  'details': {'can_edit': False,
#   'notification_level': 1,
#   'can_create_post': True,
#   'can_reply_as_new_topic': True,
#   'can_flag_topic': True,
#   'participants': [{'id': 4387,
#     'username': 'Adityach1',
#     'name': 'Aditya choudhary',
#     'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/adityach1/{size}/67114_2.png',
#     'post_count': 1,
#     'primary_group_name': 'ds-students',
#     'flair_name': 'ds-students',
#     'flair_url': None,
#     'flair_color': '',
#     'flair_bg_color': '',
#     'flair_group_id': 294,
#     'trust_level': 1},
#    {'id': 15475,
#     'username': '22f3002293',
#     'name': 'Rajat Goel',
#     'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/22f3002293/{size}/92210_2.png',
#     'post_count': 1,
#     'primary_group_name': 'ds-students',
#     'flair_name': 'ds-students',
#     'flair_url': None,
#     'flair_color': '',
#     'flair_bg_color': '',
#     'flair_group_id': 294,
#     'trust_level': 2},
#    {'id': 7742,
#     'username': '21f3000745',
#     'name': 'Tanya kamboj',
#     'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/21f3000745/{size}/638_2.png',
#     'post_count': 1,
#     'primary_group_name': 'ds-students',
#     'flair_name': 'ds-students',
#     'flair_url': None,
#     'flair_color': '',
#     'flair_bg_color': '',
#     'flair_group_id': 294,
#     'trust_level': 1},
#    {'id': 16094,
#     'username': 'carlton',
#     'name': "Carlton D'Silva",
#     'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/carlton/{size}/56317_2.png',
#     'post_count': 1,
#     'primary_group_name': 'ds-students',
#     'flair_name': 'ds-students',
#     'flair_url': None,
#     'flair_color': '',
#     'flair_bg_color': '',
#     'flair_group_id': 294,
#     'trust_level': 3}],
#   'created_by': {'id': 7742,
#    'username': '21f3000745',
#    'name': 'Tanya kamboj',
#    'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/21f3000745/{size}/638_2.png'},
#   'last_poster': {'id': 4387,
#    'username': 'Adityach1',
#    'name': 'Aditya choudhary',
#    'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/adityach1/{size}/67114_2.png'}},
#  'pending_posts': [],
#  'bookmarks': []}

# %%
import os
from tqdm import tqdm
from extract_text import clean_html
from embed import get_chunks

# %%
DISCOURSE_DIR = 'raw-data/Discourse-data'

import re
def extract_europe1_urls(text):
    # Regex pattern to find URLs starting with 'https://europe1'
    pattern = r'https://europe1[^"\s]+'
    urls = re.findall(pattern, text)
    return urls

discourse_files = [f for f in os.listdir(DISCOURSE_DIR) if f.endswith('.json')]
print(f"Found {len(discourse_files)} Discourse JSON files to process")

total_chunks = 0
c = 0
for file_name in tqdm(discourse_files, desc="Processing Discourse files"):

    file_path = os.path.join(DISCOURSE_DIR, file_name)
    with open(file_path, 'r', encoding='utf-8') as file:
        data = json.load(file)
        
        # Extract topic information
        topic_id = data.get('id')
        topic_title = data.get('title', '')
        topic_slug = data.get('slug', '')
        print(f'{topic_id}\n {topic_title}')
        
        # Process each post in the topic
        posts = data.get('post_stream', {}).get('posts', [])
        
        for post in posts:
            post_id = post.get('id')
            post_number = post.get('post_number')
            author = post.get('username', '')
            created_at = post.get('created_at', '')
            likes = post.get('like_count', 0)
            html_content = post.get('cooked', '')
            urls =  extract_europe1_urls(html_content) if extract_europe1_urls(html_content) else None
            
            print(urls)
            
            # Clean HTML content
            clean_content = clean_html(html_content)
            # print(clean_content)
            
            # Skip if content is too short
            if len(clean_content) < 20:
                continue
            
            # Create post URL with proper format
            url = f"https://discourse.onlinedegree.iitm.ac.in/t/{topic_slug}/{topic_id}/{post_number}"
            
            # Split content into chunks
            chunks = get_chunks(clean_content)
            print(''.join(chunks))
            print()
            
            # Store chunks in database
            # for i, chunk in enumerate(chunks):
    c += 1
    # if c == 10:
    #     break
    break
    print('\n\n')
# Out:
# Found 118 Discourse JSON files to process
# Processing Discourse files:   0%|          | 0/118 [00:00<?, ?it/s]
# 161071
#  Which subject to choose in jan term
# None
# Hii all…i know this may not be the correct platform to ask this question. Actually i have 3 diploma subjects to cover - MLP, JAVA, TDS. So which 2 subject should i choose for this term?
#
# None
# Don’t take TDS, this subject should be taken in the end else you might have some problem
#
# None
# TDS at the end best. Gives you the best chance of doing well in it. Kind regards
#
# None
# Yes you should do tds after mlp only it really help you alot trust me

# %%
discourse_files = [f for f in os.listdir(DISCOURSE_DIR) if f.endswith('.json')]
print(f"Found {len(discourse_files)} Discourse JSON files to process")
# Out:
# Found 118 Discourse JSON files to process

# %%
discourse_files
# Out:
# ['topic_161071.json',
#  'topic_161072.json',
#  'topic_161083.json',
#  'topic_161120.json',
#  'topic_161214.json',
#  'topic_162425.json',
#  'topic_163144.json',
#  'topic_163147.json',
#  'topic_163158.json',
#  'topic_163224.json',
#  'topic_163241.json',
#  'topic_163247.json',
#  'topic_163381.json',
#  'topic_163765.json',
#  'topic_164089.json',
#  'topic_164147.json',
#  'topic_164205.json',
#  'topic_164214.json',
#  'topic_164277.json',
#  'topic_164291.json',
#  'topic_164460.json',
#  'topic_164462.json',
#  'topic_164737.json',
#  'topic_164869.json',
#  'topic_165142.json',
#  'topic_165396.json',
#  'topic_165416.json',
#  'topic_165433.json',
#  'topic_165593.json',
#  'topic_165687.json',
#  'topic_165746.json',
#  'topic_165830.json',
#  'topic_165922.json',
#  'topic_165959.json',
#  'topic_166100.json',
#  'topic_166189.json',
#  'topic_166303.json',
#  'topic_166349.json',
#  'topic_166357.json',
#  'topic_166498.json',
#  'topic_166576.json',
#  'topic_166593.json',
#  'topic_166634.json',
#  'topic_166647.json',
#  'topic_166651.json',
#  'topic_166738.json',
#  'topic_166816.json',
#  'topic_166866.json',
#  'topic_166891.json',
#  'topic_167072.json',
#  'topic_167172.json',
#  'topic_167344.json',
#  'topic_167410.json',
#  'topic_167415.json',
#  'topic_167471.json',
#  'topic_167679.json',
#  'topic_167699.json',
#  'topic_167878.json',
#  'topic_168011.json',
#  'topic_168017.json',
#  'topic_168057.json',
#  'topic_168142.json',
#  'topic_168143.json',
#  'topic_168303.json',
#  'topic_168310.json',
#  'topic_168384.json',
#  'topic_168449.json',
#  'topic_168458.json',
#  'topic_168476.json',
#  'topic_168482.json',
#  'topic_168506.json',
#  'topic_168515.json',
#  'topic_168537.json',
#  'topic_168567.json',
#  'topic_168825.json',
#  'topic_168832.json',
#  'topic_168901.json',
#  'topic_168916.json',
#  'topic_168943.json',
#  'topic_168987.json',
#  'topic_169029.json',
#  'topic_169045.json',
#  'topic_169247.json',
#  'topic_169283.json',
#  'topic_169352.json',
#  'topic_169369.json',
#  'topic_169393.json',
#  'topic_169456.json',
#  'topic_169807.json',
#  'topic_169888.json',
#  'topic_170131.json',
#  'topic_170147.json',
#  'topic_170309.json',
#  'topic_170413.json',
#  'topic_171054.json',
#  'topic_171141.json',
#  'topic_171422.json',
#  'topic_171428.json',
#  'topic_171473.json',
#  'topic_171477.json',
#  'topic_171485.json',
#  'topic_171500.json',
#  'topic_171515.json',
#  'topic_171525.json',
#  'topic_171541.json',
#  'topic_171668.json',
#  'topic_171672.json',
#  'topic_171798.json',
#  'topic_171999.json',
#  'topic_172021.json',
#  'topic_172246.json',
#  'topic_172254.json',
#  'topic_172333.json',
#  'topic_172373.json',
#  'topic_172471.json',
#  'topic_172497.json',
#  'topic_172546.json',
#  'topic_172707.json']

# %%
import urllib
url = "https://europe1.discourse-cdn.com/flex013/uploads/iitm/original/3X/f/8/f8af7c6e2fe001c8bf000605b52c903e1b0e6fe1.png"
filename = "downloaded_image.png"

opener = urllib.request.build_opener()
opener.addheaders = [('User-Agent', 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)')]
urllib.request.install_opener(opener)
urllib.request.urlretrieve(url, filename)
print("Image saved successfully!")
# Out:
# Image saved successfully!

# %%
file_path = os.path.join(DISCOURSE_DIR, r'topic_171500.json')

with open(file_path, 'r', encoding='utf-8') as file:
    data = json.load(file)
    
my_posts = data.get('post_stream', {}).get('posts', [])

# %%
for post in my_posts:
    # print(post)
    post_id = post.get('id')
    post_number = post.get('post_number')
    author = post.get('username', '')
    created_at = post.get('created_at', '')
    likes = post.get('like_count', 0)
    html_content = post.get('cooked', '')
    urls = extract_europe1_urls(html_content)
    print(urls)
    
    # Clean HTML content
    clean_content = clean_html(html_content)
    print(clean_content)
    
    # Skip if content is too short
    if len(clean_content) < 20:
        continue
    
    # Create post URL with proper format
    url = f"https://discourse.onlinedegree.iitm.ac.in/t/{topic_slug}/{topic_id}/{post_number}"
    
    # Split content into chunks
    chunks = get_chunks(clean_content)
    print(chunks)
    print()
# Out:
# []
# I have submitted GA 7 in TDS multiple times, inspite of this it is showing not submitted. Please inspect
# ['I have submitted GA 7 in TDS multiple times, inspite of this it is showing not submitted. Please inspect']
#
# []
# @carlton @POD_TEAM how to peer review for GA7 where is the link??
# ['@carlton @POD_TEAM how to peer review for GA7 where is the link??']
#
# []
# Dont worry about seek portal. GA 7 scores will only get pushed once peer reviews are done. (roughly 3 days before end term). Kind regards
# ['Dont worry about seek portal. GA 7 scores will only get pushed once peer reviews are done. (roughly 3 days before end term). Kind regards']
#
# []
# @carlton @Jivraj What is to be done if the student in question has not done a question? We are required to fill an answer in the quantitative part. We can’t leave it blank.
# ['@carlton @Jivraj What is to be done if the student in question has not done a question? We are required to fill an answer in the quantitative part. We can’t leave it blank.']
#
# []
# Just put zero there. Since all the quantitative answers are positive.
# ['Just put zero there. Since all the quantitative answers are positive.']
#
# []
# Hi Sir, How to get to know about the peer reveiew , till now i have not got any intimation for doing peer review
# ['Hi Sir, How to get to know about the peer reveiew , till now i have not got any intimation for doing peer review']
#
# []
# You were sent an email about it. With the peers to review. It came from the official TDS email. You were sent an email on the 1st of April. Kind regards
# ['You were sent an email about it. With the peers to review. It came from the official TDS email. You were sent an email on the 1st of April. Kind regards']
#
# ['https://europe1.discourse-cdn.com/flex013/uploads/iitm/original/3X/5/c/5c4178ae6580442d7ab92893ab19c065e7e9b672.jpeg', 'https://europe1.discourse-cdn.com/flex013/uploads/iitm/optimized/3X/5/c/5c4178ae6580442d7ab92893ab19c065e7e9b672_2_690x188.jpeg', 'https://europe1.discourse-cdn.com/flex013/uploads/iitm/optimized/3X/5/c/5c4178ae6580442d7ab92893ab19c065e7e9b672_2_690x188.jpeg,', 'https://europe1.discourse-cdn.com/flex013/uploads/iitm/optimized/3X/5/c/5c4178ae6580442d7ab92893ab19c065e7e9b672_2_1035x282.jpeg', 'https://europe1.discourse-cdn.com/flex013/uploads/iitm/original/3X/5/c/5c4178ae6580442d7ab92893ab19c065e7e9b672.jpeg']
# Hi @carlton sir, I have received the bonus marks email with 5 additional HTML files for peer review. However, I noticed that one of these files was also included in the initial peer grading email. Could you please clarify if I should fill out the peer review form for this particular file again, or should I skip it since it has already been graded? 1000041565 1280×349 87.7 KB
# ['Hi @carlton sir, I have received the bonus marks email with 5 additional HTML files for peer review. However, I noticed that one of these files was also included in the initial peer grading email. Could you please clarify if I should fill out the peer review form for this particular file again, or should I skip it since it has already been graded? 1000041565 1280×349 87.7 KB']
#
# []
# Thanks we have made a correction and sent an email.
# ['Thanks we have made a correction and sent an email.']

# %%
posts
# Out:
# [{'id': 619552,
#   'name': 'Shambhavi Verma',
#   'username': '24f2003130',
#   'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/24f2003130/{size}/132501_2.png',
#   'created_at': '2025-04-15T09:59:51.136Z',
#   'cooked': '<p>Hi <a class="mention" href="/u/carlton">@carlton</a> and <a class="mention" href="/u/jivraj">@Jivraj</a> sir,</p>\n<p>I appeared for the end term examination held on 13th April 2025 during the FN shift. I would like to bring to your attention that the exam interface did not provide an option for multiple selections. However, a few questions appeared to have multiple correct answers.</p>\n<p>I have noted down the specific questions and the corresponding options I believe to be correct.So, kindly review them and let me know if there were any errors in my understanding of the questions. The questions are as follows:</p>\n<p><div class="lightbox-wrapper"><a class="lightbox" href="https://europe1.discourse-cdn.com/flex013/uploads/iitm/original/3X/f/d/fd08e14665989ccea8f5a547b569521575208ae8.jpeg" data-download-href="/uploads/short-url/A6rPaqEeHL4nw1GGBGp4tKdfWWs.jpeg?dl=1" title="1000042547" rel="noopener nofollow ugc"><img src="https://europe1.discourse-cdn.com/flex013/uploads/iitm/optimized/3X/f/d/fd08e14665989ccea8f5a547b569521575208ae8_2_690x369.jpeg" alt="1000042547" data-base62-sha1="A6rPaqEeHL4nw1GGBGp4tKdfWWs" width="690" height="369" srcset="https://europe1.discourse-cdn.com/flex013/uploads/iitm/optimized/3X/f/d/fd08e14665989ccea8f5a547b569521575208ae8_2_690x369.jpeg, https://europe1.discourse-cdn.com/flex013/uploads/iitm/optimized/3X/f/d/fd08e14665989ccea8f5a547b569521575208ae8_2_1035x553.jpeg 1.5x, https://europe1.discourse-cdn.com/flex013/uploads/iitm/original/3X/f/d/fd08e14665989ccea8f5a547b569521575208ae8.jpeg 2x" data-dominant-color="F0E8E6"><div class="meta"><svg class="fa d-icon d-icon-far-image svg-icon" aria-hidden="true"><use href="#far-image"></use></svg><span class="filename">1000042547</span><span class="informations">1080×578 187 KB</span><svg class="fa d-icon d-icon-discourse-expand svg-icon" aria-hidden="true"><use href="#discourse-expand"></use></svg></div></a></div></p>\n<p>Question 2: Fields needed to filter “POST requests under /images/ from 15:00 to 18:00 on Mondays”</p>\n<p>To filter such logs, we need:</p>\n<p>Time → for the hour and the day (Monday)<br>\nMethod → to filter POST<br>\nURL → to filter /images/</p>\n<p>So, the correct minimal set is:</p>\n<blockquote>\n<p><img src="https://emoji.discourse-cdn.com/google/white_check_mark.png?v=14" title=":white_check_mark:" class="emoji" alt=":white_check_mark:" loading="lazy" width="20" height="20"> Time, Method, URL</p>\n</blockquote>\n<p>Time → needed <img src="https://emoji.discourse-cdn.com/google/white_check_mark.png?v=14" title=":white_check_mark:" class="emoji" alt=":white_check_mark:" loading="lazy" width="20" height="20"><br>\nMethod → needed <img src="https://emoji.discourse-cdn.com/google/white_check_mark.png?v=14" title=":white_check_mark:" class="emoji" alt=":white_check_mark:" loading="lazy" width="20" height="20"><br>\nURL → needed <img src="https://emoji.discourse-cdn.com/google/white_check_mark.png?v=14" title=":white_check_mark:" class="emoji" alt=":white_check_mark:" loading="lazy" width="20" height="20"><br>\nReferer → not needed, but not harmful</p>\n<p>So this option includes all the necessary fields, just with one extra — which doesn’t invalidate it.</p>\n<p><div class="lightbox-wrapper"><a class="lightbox" href="https://europe1.discourse-cdn.com/flex013/uploads/iitm/original/3X/9/0/9062a032d89a4b2b049ca34b23905d501cba7913.jpeg" data-download-href="/uploads/short-url/kBi3KxCTBUs9L4ifYXzDfQKdZRh.jpeg?dl=1" title="1000042548" rel="noopener nofollow ugc"><img src="https://europe1.discourse-cdn.com/flex013/uploads/iitm/optimized/3X/9/0/9062a032d89a4b2b049ca34b23905d501cba7913_2_690x192.jpeg" alt="1000042548" data-base62-sha1="kBi3KxCTBUs9L4ifYXzDfQKdZRh" width="690" height="192" srcset="https://europe1.discourse-cdn.com/flex013/uploads/iitm/optimized/3X/9/0/9062a032d89a4b2b049ca34b23905d501cba7913_2_690x192.jpeg, https://europe1.discourse-cdn.com/flex013/uploads/iitm/optimized/3X/9/0/9062a032d89a4b2b049ca34b23905d501c ...
#   'post_number': 1,
#   'post_type': 1,
#   'posts_count': 16,
#   'updated_at': '2025-04-15T09:59:51.136Z',
#   'reply_count': 0,
#   'reply_to_post_number': None,
#   'quote_count': 0,
#   'incoming_link_count': 52,
#   'reads': 117,
#   'readers_count': 116,
#   'score': 373.2,
#   'yours': False,
#   'topic_id': 172707,
#   'topic_slug': 'queries-regarding-end-term-exam-solutions',
#   'display_username': 'Shambhavi Verma',
#   'primary_group_name': 'ds-students',
#   'flair_name': 'ds-students',
#   'flair_url': None,
#   'flair_bg_color': '',
#   'flair_color': '',
#   'flair_group_id': 294,
#   'badges_granted': [],
#   'version': 1,
#   'can_edit': False,
#   'can_delete': False,
#   'can_recover': False,
#   'can_see_hidden_post': False,
#   'can_wiki': False,
#   'read': False,
#   'user_title': '',
#   'bookmarked': False,
#   'actions_summary': [{'id': 2, 'count': 6, 'can_act': True},
#    {'id': 6, 'can_act': True},
#    {'id': 3, 'can_act': True},
#    {'id': 4, 'can_act': True},
#    {'id': 8, 'can_act': True},
#    {'id': 10, 'can_act': True},
#    {'id': 7, 'can_act': True}],
#   'moderator': False,
#   'admin': False,
#   'staff': False,
#   'user_id': 30376,
#   'hidden': False,
#   'trust_level': 1,
#   'deleted_at': None,
#   'user_deleted': False,
#   'edit_reason': None,
#   'can_view_edit_history': True,
#   'wiki': False,
#   'post_url': '/t/queries-regarding-end-term-exam-solutions/172707/1',
#   'user_cakedate': '2024-06-02',
#   'user_birthdate': '1904-09-28',
#   'reactions': [{'id': 'heart', 'type': 'emoji', 'count': 6}],
#   'current_user_reaction': None,
#   'reaction_users_count': 6,
#   'current_user_used_main_reaction': False,
#   'can_accept_answer': False,
#   'can_unaccept_answer': False,
#   'accepted_answer': False,
#   'topic_accepted_answer': None,
#   'can_vote': False},
#  {'id': 619868,
#   'name': 'Koustubh Ramakrishnan',
#   'username': 'koustubhr',
#   'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/koustubhr/{size}/68167_2.png',
#   'created_at': '2025-04-15T17:19:29.506Z',
#   'cooked': '<p>Agree &amp; second all thoughts shared by <a class="mention" href="/u/24f2003130">@24f2003130</a> above.</p>\n<ul>\n<li>\n<p>I also wanted to clarify on this question on filtered entries. The question mentions that a list filtered_entries is being created , and with the way the question is structured it seems like the filtering conditions mentioned in the question have already been applied. In that case <code>len(filtered entries)</code> seems to be correct. However the right answer is marked ‘None of these’ .<br>\n<div class="lightbox-wrapper"><a class="lightbox" href="https://europe1.discourse-cdn.com/flex013/uploads/iitm/original/3X/f/5/f5f549e906df1006709b3257742fff4b52f416d0.png" data-download-href="/uploads/short-url/z5Qvydw8nYEYuIyQ5RZLKdwMgzS.png?dl=1" title="image" rel="noopener nofollow ugc"><img src="https://europe1.discourse-cdn.com/flex013/uploads/iitm/optimized/3X/f/5/f5f549e906df1006709b3257742fff4b52f416d0_2_690x245.png" alt="image" data-base62-sha1="z5Qvydw8nYEYuIyQ5RZLKdwMgzS" width="690" height="245" srcset="https://europe1.discourse-cdn.com/flex013/uploads/iitm/optimized/3X/f/5/f5f549e906df1006709b3257742fff4b52f416d0_2_690x245.png, https://europe1.discourse-cdn.com/flex013/uploads/iitm/optimized/3X/f/5/f5f549e906df1006709b3257742fff4b52f416d0_2_1035x367.png 1.5x, https://europe1.discourse-cdn.com/flex013/uploads/iitm/original/3X/f/5/f5f549e906df1006709b3257742fff4b52f416d0.png 2x" data-dominant-color="F2EFEE"><div class="meta"><svg class="fa d-icon d-icon-far-image svg-icon" aria-hidden="true"><use href="#far-image"></use></svg><span class="filename">image</span><span class="informations">1108×394 81.9 KB</span><svg class="fa d-icon d-icon-discourse-expand svg-icon" aria-hidden="true"><use href="#discourse-expand"></use></svg></div></a></div></p>\n</li>\n<li>\n<p>The valid log entry had me stumped too, option 1 and 4 both look absolutely fine yet only option 4 is marked correct.</p>\n</li>\n<li>\n<p>Also, only POST request is not idempotent, all other requests are idempotent yet only PUT is marked correct.</p>\n</li>\n</ul>\n<p>Request you to please clarify and consider these points.</p>',
#   'post_number': 2,
#   'post_type': 1,
#   'posts_count': 16,
#   'updated_at': '2025-04-15T17:19:29.506Z',
#   'reply_count': 1,
#   'reply_to_post_number': None,
#   'quote_count': 0,
#   'incoming_link_count': 3,
#   'reads': 97,
#   'readers_count': 96,
#   'score': 84.4,
#   'yours': False,
#   'topic_id': 172707,
#   'topic_slug': 'queries-regarding-end-term-exam-solutions',
#   'display_username': 'Koustubh Ramakrishnan',
#   'primary_group_name': 'ds-students',
#   'flair_name': 'ds-students',
#   'flair_url': None,
#   'flair_bg_color': '',
#   'flair_color': '',
#   'flair_group_id': 294,
#   'badges_granted': [],
#   'version': 1,
#   'can_edit': False,
#   'can_delete': False,
#   'can_recover': False,
#   'can_see_hidden_post': False,
#   'can_wiki': False,
#   'read': False,
#   'user_title': None,
#   'bookmarked': False,
#   'actions_summary': [{'id': 2, 'count': 3, 'can_act': True},
#    {'id': 6, 'can_act': True},
#    {'id': 3, 'can_act': True},
#    {'id': 4, 'can_act': True},
#    {'id': 8, 'can_act': True},
#    {'id': 10, 'can_act': True},
#    {'id': 7, 'can_act': True}],
#   'moderator': False,
#   'admin': False,
#   'staff': False,
#   'user_id': 32940,
#   'hidden': False,
#   'trust_level': 1,
#   'deleted_at': None,
#   'user_deleted': False,
#   'edit_reason': None,
#   'can_view_edit_history': True,
#   'wiki': False,
#   'post_url': '/t/queries-regarding-end-term-exam-solutions/172707/2',
#   'user_cakedate': '2024-06-04',
#   'reactions': [{'id': 'heart', 'type': 'emoji', 'count': 3}],
#   'current_user_reaction': None,
#   'reaction_users_count': 3,
#   'current_user_used_main_reaction': False,
#   'can_accept_answer': False,
#   'can_unaccept_answer': False,
#   'accepted_answer': False,
#   'topic_accepted_answer': None},
#  {'id': 619891,
#   'name': 'Shivaditya Bhattacharya',
#   'username': '22f3000819',
#   'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/22f3000819/{size}/66738_2.png',
#   'created_at': '2025-04-15T18:13:03.725Z',
#   'cooked': '<p>Yes <a class="mention" href="/u/carlton">@carlton</a> the wording of the question made it seem like the filters were already applied on the list <code>filtered_entries</code>.</p>',
#   'post_number': 3,
#   'post_type': 1,
#   'posts_count': 16,
#   'updated_at': '2025-04-15T18:13:03.725Z',
#   'reply_count': 0,
#   'reply_to_post_number': 2,
#   'quote_count': 0,
#   'incoming_link_count': 2,
#   'reads': 142,
#   'readers_count': 141,
#   'score': 38.2,
#   'yours': False,
#   'topic_id': 172707,
#   'topic_slug': 'queries-regarding-end-term-exam-solutions',
#   'display_username': 'Shivaditya Bhattacharya',
#   'primary_group_name': 'ds-students',
#   'flair_name': 'ds-students',
#   'flair_url': None,
#   'flair_bg_color': '',
#   'flair_color': '',
#   'flair_group_id': 294,
#   'badges_granted': [],
#   'version': 1,
#   'can_edit': False,
#   'can_delete': False,
#   'can_recover': False,
#   'can_see_hidden_post': False,
#   'can_wiki': False,
#   'read': False,
#   'user_title': '',
#   'reply_to_user': {'id': 32940,
#    'username': 'koustubhr',
#    'name': 'Koustubh Ramakrishnan',
#    'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/koustubhr/{size}/68167_2.png'},
#   'bookmarked': False,
#   'actions_summary': [{'id': 2, 'can_act': True},
#    {'id': 6, 'can_act': True},
#    {'id': 3, 'can_act': True},
#    {'id': 4, 'can_act': True},
#    {'id': 8, 'can_act': True},
#    {'id': 10, 'can_act': True},
#    {'id': 7, 'can_act': True}],
#   'moderator': False,
#   'admin': False,
#   'staff': False,
#   'user_id': 16002,
#   'hidden': False,
#   'trust_level': 1,
#   'deleted_at': None,
#   'user_deleted': False,
#   'edit_reason': None,
#   'can_view_edit_history': True,
#   'wiki': False,
#   'post_url': '/t/queries-regarding-end-term-exam-solutions/172707/3',
#   'user_cakedate': '2023-01-25',
#   'user_birthdate': '1904-03-07',
#   'reactions': [],
#   'current_user_reaction': None,
#   'reaction_users_count': 0,
#   'current_user_used_main_reaction': False,
#   'can_accept_answer': False,
#   'can_unaccept_answer': False,
#   'accepted_answer': False,
#   'topic_accepted_answer': None},
#  {'id': 620130,
#   'name': 'Prasanna',
#   'username': 'iamprasna',
#   'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/iamprasna/{size}/13977_2.png',
#   'created_at': '2025-04-16T10:08:58.668Z',
#   'cooked': '<h1><a name="p-620130-clarifications-on-queries-1" class="anchor" href="#p-620130-clarifications-on-queries-1"></a>Clarifications on Queries</h1>\n<ol>\n<li>\n<p><strong>Which of the following is a valid log entry based on the provided format?</strong><br>\nDue to a technical issue in the portal, both options 1 and 4 are correct answers. The final scoring has been adjusted accordingly, and full marks will be awarded for either response.</p>\n</li>\n<li>\n<p><strong>HTTP method is idempotent</strong><br>\nThis question has been excluded from scoring as three methods (GET, PUT, and DELETE) are idempotent, with only POST being non-idempotent.</p>\n</li>\n<li>\n<p><strong>Entries with 404 status code</strong><br>\nAlthough the instructions did not explicitly state that filters applied for status code 404, we acknowledge this ambiguity. Full credit will be awarded for both option 1 and option 4.</p>\n</li>\n<li>\n<p><strong>Which of the following fields are necessary to filter “POST requests made for pages under /images/ from 15:00 to 18:00 on Mondays”?</strong><br>\nOption A (Time, Request, Method, URL) is correct because:</p>\n</li>\n</ol>\n<ul>\n<li>Option B includes Size and Status, which aren’t needed for filtering by time, method, and URL</li>\n<li>Option C includes Referer, which is unnecessary unless filtering by source page</li>\n<li>Option D includes Status and Server, which aren’t relevant for this specific filtering requirement</li>\n</ul>',
#   'post_number': 4,
#   'post_type': 1,
#   'posts_count': 16,
#   'updated_at': '2025-04-16T10:08:58.668Z',
#   'reply_count': 2,
#   'reply_to_post_number': None,
#   'quote_count': 0,
#   'incoming_link_count': 98,
#   'reads': 138,
#   'readers_count': 137,
#   'score': 557.4,
#   'yours': False,
#   'topic_id': 172707,
#   'topic_slug': 'queries-regarding-end-term-exam-solutions',
#   'display_username': 'Prasanna',
#   'primary_group_name': 'course_support',
#   'flair_name': 'course_support',
#   'flair_url': 'scale-balanced',
#   'flair_bg_color': '0040ff',
#   'flair_color': '1affc6',
#   'flair_group_id': 41,
#   'badges_granted': [],
#   'version': 1,
#   'can_edit': False,
#   'can_delete': False,
#   'can_recover': False,
#   'can_see_hidden_post': False,
#   'can_wiki': False,
#   'read': False,
#   'user_title': 'Course_Team',
#   'title_is_group': True,
#   'bookmarked': False,
#   'actions_summary': [{'id': 2, 'count': 2, 'can_act': True},
#    {'id': 6, 'can_act': True},
#    {'id': 3, 'can_act': True},
#    {'id': 4, 'can_act': True},
#    {'id': 8, 'can_act': True},
#    {'id': 10, 'can_act': True},
#    {'id': 7, 'can_act': True}],
#   'moderator': False,
#   'admin': False,
#   'staff': False,
#   'user_id': 9398,
#   'hidden': False,
#   'trust_level': 4,
#   'deleted_at': None,
#   'user_deleted': False,
#   'edit_reason': None,
#   'can_view_edit_history': True,
#   'wiki': False,
#   'post_url': '/t/queries-regarding-end-term-exam-solutions/172707/4',
#   'user_cakedate': '2022-01-03',
#   'reactions': [{'id': 'heart', 'type': 'emoji', 'count': 2}],
#   'current_user_reaction': None,
#   'reaction_users_count': 2,
#   'current_user_used_main_reaction': False,
#   'can_accept_answer': False,
#   'can_unaccept_answer': False,
#   'accepted_answer': False,
#   'topic_accepted_answer': None},
#  {'id': 620133,
#   'name': 'Shambhavi Verma',
#   'username': '24f2003130',
#   'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/24f2003130/{size}/132501_2.png',
#   'created_at': '2025-04-16T10:15:01.944Z',
#   'cooked': '<p>Thank you for the clarification provided regarding Question 4 and resolution of errors in other questions. I understand the reasoning behind choosing Option A (Time, Request, Method, URL). However, I respectfully believe Option C (Time, Method, URL, Referer) is more accurate for the following reasons:</p>\n<ol>\n<li>\n<p>Redundancy in Option A:<br>\nThe Request field already contains the HTTP method, URL, and protocol (e.g., “POST /images/logo.png HTTP/1.1”). Including both Request and separate Method and URL fields introduces redundancy. If we already extract Method and URL separately for filtering, the full Request field becomes unnecessary.</p>\n</li>\n<li>\n<p>Simplicity in Filtering:<br>\nFiltering for “POST requests under /images/” from 15:00 to 18:00 on Mondays can be done using:</p>\n</li>\n</ol>\n<p>Time → for checking the hour and weekday.</p>\n<p>Method → to filter only POST.</p>\n<p>URL → to ensure the request is under /images/.</p>\n<p>Thus, Option C (Time, Method, URL, Referer) already includes all needed fields. While Referer is not essential, it doesn’t interfere with the filtering and might be useful in future extended filtering cases (e.g., source tracking). Therefore, Option C is complete and accurate without being redundant.</p>\n<ol start="3">\n<li>Consistency with Log Parsing Practices:<br>\nIn most log analysis scripts or systems (e.g., Python’s re or pandas parsing of logs), Method and URL are parsed from Request for separate use. This further supports the idea that including Request alongside Method and URL is not best practice.</li>\n</ol>',
#   'post_number': 5,
#   'post_type': 1,
#   'posts_count': 16,
#   'updated_at': '2025-04-16T10:15:01.944Z',
#   'reply_count': 0,
#   'reply_to_post_number': 4,
#   'quote_count': 0,
#   'incoming_link_count': 8,
#   'reads': 134,
#   'readers_count': 133,
#   'score': 66.6,
#   'yours': False,
#   'topic_id': 172707,
#   'topic_slug': 'queries-regarding-end-term-exam-solutions',
#   'display_username': 'Shambhavi Verma',
#   'primary_group_name': 'ds-students',
#   'flair_name': 'ds-students',
#   'flair_url': None,
#   'flair_bg_color': '',
#   'flair_color': '',
#   'flair_group_id': 294,
#   'badges_granted': [],
#   'version': 1,
#   'can_edit': False,
#   'can_delete': False,
#   'can_recover': False,
#   'can_see_hidden_post': False,
#   'can_wiki': False,
#   'read': False,
#   'user_title': '',
#   'reply_to_user': {'id': 9398,
#    'username': 'iamprasna',
#    'name': 'Prasanna',
#    'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/iamprasna/{size}/13977_2.png'},
#   'bookmarked': False,
#   'actions_summary': [{'id': 2, 'can_act': True},
#    {'id': 6, 'can_act': True},
#    {'id': 3, 'can_act': True},
#    {'id': 4, 'can_act': True},
#    {'id': 8, 'can_act': True},
#    {'id': 10, 'can_act': True},
#    {'id': 7, 'can_act': True}],
#   'moderator': False,
#   'admin': False,
#   'staff': False,
#   'user_id': 30376,
#   'hidden': False,
#   'trust_level': 1,
#   'deleted_at': None,
#   'user_deleted': False,
#   'edit_reason': None,
#   'can_view_edit_history': True,
#   'wiki': False,
#   'post_url': '/t/queries-regarding-end-term-exam-solutions/172707/5',
#   'user_cakedate': '2024-06-02',
#   'user_birthdate': '1904-09-28',
#   'reactions': [],
#   'current_user_reaction': None,
#   'reaction_users_count': 0,
#   'current_user_used_main_reaction': False,
#   'can_accept_answer': False,
#   'can_unaccept_answer': False,
#   'accepted_answer': False,
#   'topic_accepted_answer': None},
#  {'id': 620467,
#   'name': 'Shivaditya Bhattacharya',
#   'username': '22f3000819',
#   'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/22f3000819/{size}/66738_2.png',
#   'created_at': '2025-04-16T18:28:35.206Z',
#   'cooked': '<p>Sir, regarding point 3, score-checker tells a different story. While all the other changes have been made with the same reflecting in the score, that question still says “The question and answer remain the same . No changes required”, which is different from your post.</p>\n<p><img src="https://europe1.discourse-cdn.com/flex013/uploads/iitm/optimized/3X/4/0/404e7b25f4155d41d4939b07fd45fa3c120beadd_2_690x31.png" alt="image" data-base62-sha1="9aSHAfq31r6LUlSOz4aOuDJd1s9" width="690" height="31" srcset="https://europe1.discourse-cdn.com/flex013/uploads/iitm/optimized/3X/4/0/404e7b25f4155d41d4939b07fd45fa3c120beadd_2_690x31.png, https://europe1.discourse-cdn.com/flex013/uploads/iitm/optimized/3X/4/0/404e7b25f4155d41d4939b07fd45fa3c120beadd_2_1035x46.png 1.5x, https://europe1.discourse-cdn.com/flex013/uploads/iitm/optimized/3X/4/0/404e7b25f4155d41d4939b07fd45fa3c120beadd_2_1380x62.png 2x" data-dominant-color="EBEEF2"><br>\n<div class="lightbox-wrapper"><a class="lightbox" href="https://europe1.discourse-cdn.com/flex013/uploads/iitm/original/3X/9/1/91a843fad0075c603424114af0cfca114941a304.png" data-download-href="/uploads/short-url/kMxJUqb03TNPiIf0e1wW5LmlOh6.png?dl=1" title="image" rel="noopener nofollow ugc"><img src="https://europe1.discourse-cdn.com/flex013/uploads/iitm/optimized/3X/9/1/91a843fad0075c603424114af0cfca114941a304_2_690x263.png" alt="image" data-base62-sha1="kMxJUqb03TNPiIf0e1wW5LmlOh6" width="690" height="263" srcset="https://europe1.discourse-cdn.com/flex013/uploads/iitm/optimized/3X/9/1/91a843fad0075c603424114af0cfca114941a304_2_690x263.png, https://europe1.discourse-cdn.com/flex013/uploads/iitm/original/3X/9/1/91a843fad0075c603424114af0cfca114941a304.png 1.5x, https://europe1.discourse-cdn.com/flex013/uploads/iitm/original/3X/9/1/91a843fad0075c603424114af0cfca114941a304.png 2x" data-dominant-color="F2F0EF"><div class="meta"><svg class="fa d-icon d-icon-far-image svg-icon" aria-hidden="true"><use href="#far-image"></use></svg><span class="filename">image</span><span class="informations">923×352 72 KB</span><svg class="fa d-icon d-icon-discourse-expand svg-icon" aria-hidden="true"><use href="#discourse-expand"></use></svg></div></a></div></p>\n<p>Can you please look into it?</p>\n<p>Thanks<br>\nRegards,<br>\nShivaditya</p>',
#   'post_number': 6,
#   'post_type': 1,
#   'posts_count': 16,
#   'updated_at': '2025-04-16T18:28:35.206Z',
#   'reply_count': 2,
#   'reply_to_post_number': 4,
#   'quote_count': 0,
#   'incoming_link_count': 2,
#   'reads': 54,
#   'readers_count': 53,
#   'score': 45.8,
#   'yours': False,
#   'topic_id': 172707,
#   'topic_slug': 'queries-regarding-end-term-exam-solutions',
#   'display_username': 'Shivaditya Bhattacharya',
#   'primary_group_name': 'ds-students',
#   'flair_name': 'ds-students',
#   'flair_url': None,
#   'flair_bg_color': '',
#   'flair_color': '',
#   'flair_group_id': 294,
#   'badges_granted': [],
#   'version': 1,
#   'can_edit': False,
#   'can_delete': False,
#   'can_recover': False,
#   'can_see_hidden_post': False,
#   'can_wiki': False,
#   'read': False,
#   'user_title': '',
#   'reply_to_user': {'id': 9398,
#    'username': 'iamprasna',
#    'name': 'Prasanna',
#    'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/iamprasna/{size}/13977_2.png'},
#   'bookmarked': False,
#   'actions_summary': [{'id': 2, 'count': 1, 'can_act': True},
#    {'id': 6, 'can_act': True},
#    {'id': 3, 'can_act': True},
#    {'id': 4, 'can_act': True},
#    {'id': 8, 'can_act': True},
#    {'id': 10, 'can_act': True},
#    {'id': 7, 'can_act': True}],
#   'moderator': False,
#   'admin': False,
#   'staff': False,
#   'user_id': 16002,
#   'hidden': False,
#   'trust_level': 1,
#   'deleted_at': None,
#   'user_deleted': False,
#   'edit_reason': None,
#   'can_view_edit_history': True,
#   'wiki': False,
#   'post_url': '/t/queries-regarding-end-term-exam-solutions/172707/6',
#   'user_cakedate': '2023-01-25',
#   'user_birthdate': '1904-03-07',
#   'reactions': [{'id': 'heart', 'type': 'emoji', 'count': 1}],
#   'current_user_reaction': None,
#   'reaction_users_count': 1,
#   'current_user_used_main_reaction': False,
#   'can_accept_answer': False,
#   'can_unaccept_answer': False,
#   'accepted_answer': False,
#   'topic_accepted_answer': None},
#  {'id': 620472,
#   'name': 'Shambhavi Verma',
#   'username': '24f2003130',
#   'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/24f2003130/{size}/132501_2.png',
#   'created_at': '2025-04-16T18:47:03.645Z',
#   'cooked': '<p><a class="mention" href="/u/iamprasna">@iamprasna</a> sir , the scores have been updated on the dashboard as well and the answer for the question in point 3 is still the same</p>\n<p>Additionally , sir I have attached the snapshot of a dec’24 TDS PYQ which is a replica of this question and the answer for the same is mention the first option.</p>\n<p><div class="lightbox-wrapper"><a class="lightbox" href="https://europe1.discourse-cdn.com/flex013/uploads/iitm/original/3X/f/d/fda110de0ada74e60ba0e160ab21463c4ebdbd44.jpeg" data-download-href="/uploads/short-url/AbHSGMuXF9zvg4FybyCD4uGyueo.jpeg?dl=1" title="1000042796" rel="noopener nofollow ugc"><img src="https://europe1.discourse-cdn.com/flex013/uploads/iitm/optimized/3X/f/d/fda110de0ada74e60ba0e160ab21463c4ebdbd44_2_690x343.jpeg" alt="1000042796" data-base62-sha1="AbHSGMuXF9zvg4FybyCD4uGyueo" width="690" height="343" srcset="https://europe1.discourse-cdn.com/flex013/uploads/iitm/optimized/3X/f/d/fda110de0ada74e60ba0e160ab21463c4ebdbd44_2_690x343.jpeg, https://europe1.discourse-cdn.com/flex013/uploads/iitm/optimized/3X/f/d/fda110de0ada74e60ba0e160ab21463c4ebdbd44_2_1035x514.jpeg 1.5x, https://europe1.discourse-cdn.com/flex013/uploads/iitm/original/3X/f/d/fda110de0ada74e60ba0e160ab21463c4ebdbd44.jpeg 2x" data-dominant-color="F6F6F6"><div class="meta"><svg class="fa d-icon d-icon-far-image svg-icon" aria-hidden="true"><use href="#far-image"></use></svg><span class="filename">1000042796</span><span class="informations">1080×538 84.7 KB</span><svg class="fa d-icon d-icon-discourse-expand svg-icon" aria-hidden="true"><use href="#discourse-expand"></use></svg></div></a></div></p>\n<p>The link for the same has been attached for your referance</p><aside class="onebox googledrive" data-onebox-src="https://drive.google.com/file/d/13RkOKhfalx4uVu7gqFYUncvJ9_-lYMMX/view?usp=drivesdk">\n  <header class="source">\n\n      <a href="https://drive.google.com/file/d/13RkOKhfalx4uVu7gqFYUncvJ9_-lYMMX/view?usp=drivesdk" target="_blank" rel="noopener nofollow ugc">drive.google.com</a>\n  </header>\n\n  <article class="onebox-body">\n      <a href="https://drive.google.com/file/d/13RkOKhfalx4uVu7gqFYUncvJ9_-lYMMX/view?usp=drivesdk" target="_blank" rel="noopener nofollow ugc"><span class="googledocs-onebox-logo g-drive-logo"></span></a>\n\n\n\n<h3><a href="https://drive.google.com/file/d/13RkOKhfalx4uVu7gqFYUncvJ9_-lYMMX/view?usp=drivesdk" target="_blank" rel="noopener nofollow ugc">IIT M FOUNDATION DIPLOMA FN EXAM QDF2 22 Dec 2024.pdf</a></h3>\n\n<p>Google Drive file.</p>\n\n  </article>\n\n  <div class="onebox-metadata">\n    \n    \n  </div>\n\n  <div style="clear: both"></div>\n</aside>\n',
#   'post_number': 7,
#   'post_type': 1,
#   'posts_count': 16,
#   'updated_at': '2025-04-17T04:17:20.826Z',
#   'reply_count': 1,
#   'reply_to_post_number': 6,
#   'quote_count': 0,
#   'incoming_link_count': 14,
#   'reads': 54,
#   'readers_count': 53,
#   'score': 100.6,
#   'yours': False,
#   'topic_id': 172707,
#   'topic_slug': 'queries-regarding-end-term-exam-solutions',
#   'display_username': 'Shambhavi Verma',
#   'primary_group_name': 'ds-students',
#   'flair_name': 'ds-students',
#   'flair_url': None,
#   'flair_bg_color': '',
#   'flair_color': '',
#   'flair_group_id': 294,
#   'badges_granted': [],
#   'version': 4,
#   'can_edit': False,
#   'can_delete': False,
#   'can_recover': False,
#   'can_see_hidden_post': False,
#   'can_wiki': False,
#   'link_counts': [{'url': 'https://drive.google.com/file/d/13RkOKhfalx4uVu7gqFYUncvJ9_-lYMMX/view?usp=drivesdk',
#     'internal': False,
#     'reflection': False,
#     'title': 'IIT M FOUNDATION DIPLOMA FN EXAM QDF2 22 Dec 2024.pdf - Google Drive',
#     'clicks': 3}],
#   'read': False,
#   'user_title': '',
#   'reply_to_user': {'id': 16002,
#    'username': '22f3000819',
#    'name': 'Shivaditya Bhattacharya',
#    'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/22f3000819/{size}/66738_2.png'},
#   'bookmarked': False,
#   'actions_summary': [{'id': 2, 'count': 1, 'can_act': True},
#    {'id': 6, 'can_act': True},
#    {'id': 3, 'can_act': True},
#    {'id': 4, 'can_act': True},
#    {'id': 8, 'can_act': True},
#    {'id': 10, 'can_act': True},
#    {'id': 7, 'can_act': True}],
#   'moderator': False,
#   'admin': False,
#   'staff': False,
#   'user_id': 30376,
#   'hidden': False,
#   'trust_level': 1,
#   'deleted_at': None,
#   'user_deleted': False,
#   'edit_reason': None,
#   'can_view_edit_history': True,
#   'wiki': False,
#   'post_url': '/t/queries-regarding-end-term-exam-solutions/172707/7',
#   'user_cakedate': '2024-06-02',
#   'user_birthdate': '1904-09-28',
#   'reactions': [{'id': 'heart', 'type': 'emoji', 'count': 1}],
#   'current_user_reaction': None,
#   'reaction_users_count': 1,
#   'current_user_used_main_reaction': False,
#   'can_accept_answer': False,
#   'can_unaccept_answer': False,
#   'accepted_answer': False,
#   'topic_accepted_answer': None},
#  {'id': 620477,
#   'name': 'Shivaditya Bhattacharya',
#   'username': '22f3000819',
#   'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/22f3000819/{size}/66738_2.png',
#   'created_at': '2025-04-16T19:04:11.803Z',
#   'cooked': '<p>That’s a great find. They’re the same question with just different parameters. Please look into it <a class="mention" href="/u/iamprasna">@iamprasna</a> sir.</p>',
#   'post_number': 8,
#   'post_type': 1,
#   'posts_count': 16,
#   'updated_at': '2025-04-16T19:04:11.803Z',
#   'reply_count': 0,
#   'reply_to_post_number': 7,
#   'quote_count': 0,
#   'incoming_link_count': 0,
#   'reads': 52,
#   'readers_count': 51,
#   'score': 10.2,
#   'yours': False,
#   'topic_id': 172707,
#   'topic_slug': 'queries-regarding-end-term-exam-solutions',
#   'display_username': 'Shivaditya Bhattacharya',
#   'primary_group_name': 'ds-students',
#   'flair_name': 'ds-students',
#   'flair_url': None,
#   'flair_bg_color': '',
#   'flair_color': '',
#   'flair_group_id': 294,
#   'badges_granted': [],
#   'version': 1,
#   'can_edit': False,
#   'can_delete': False,
#   'can_recover': False,
#   'can_see_hidden_post': False,
#   'can_wiki': False,
#   'read': False,
#   'user_title': '',
#   'reply_to_user': {'id': 30376,
#    'username': '24f2003130',
#    'name': 'Shambhavi Verma',
#    'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/24f2003130/{size}/132501_2.png'},
#   'bookmarked': False,
#   'actions_summary': [{'id': 2, 'can_act': True},
#    {'id': 6, 'can_act': True},
#    {'id': 3, 'can_act': True},
#    {'id': 4, 'can_act': True},
#    {'id': 8, 'can_act': True},
#    {'id': 10, 'can_act': True},
#    {'id': 7, 'can_act': True}],
#   'moderator': False,
#   'admin': False,
#   'staff': False,
#   'user_id': 16002,
#   'hidden': False,
#   'trust_level': 1,
#   'deleted_at': None,
#   'user_deleted': False,
#   'edit_reason': None,
#   'can_view_edit_history': True,
#   'wiki': False,
#   'post_url': '/t/queries-regarding-end-term-exam-solutions/172707/8',
#   'user_cakedate': '2023-01-25',
#   'user_birthdate': '1904-03-07',
#   'reactions': [],
#   'current_user_reaction': None,
#   'reaction_users_count': 0,
#   'current_user_used_main_reaction': False,
#   'can_accept_answer': False,
#   'can_unaccept_answer': False,
#   'accepted_answer': False,
#   'topic_accepted_answer': None},
#  {'id': 620539,
#   'name': 'Shambhavi Verma',
#   'username': '24f2003130',
#   'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/24f2003130/{size}/132501_2.png',
#   'created_at': '2025-04-17T04:17:09.060Z',
#   'cooked': '<p><a class="mention" href="/u/carlton">@carlton</a> sir and <a class="mention" href="/u/jivraj">@Jivraj</a> sir please look into this question and clarify this</p>\n<p>Thank you</p>',
#   'post_number': 9,
#   'post_type': 1,
#   'posts_count': 16,
#   'updated_at': '2025-04-17T10:37:21.272Z',
#   'reply_count': 0,
#   'reply_to_post_number': None,
#   'quote_count': 0,
#   'incoming_link_count': 2,
#   'reads': 48,
#   'readers_count': 47,
#   'score': 19.4,
#   'yours': False,
#   'topic_id': 172707,
#   'topic_slug': 'queries-regarding-end-term-exam-solutions',
#   'display_username': 'Shambhavi Verma',
#   'primary_group_name': 'ds-students',
#   'flair_name': 'ds-students',
#   'flair_url': None,
#   'flair_bg_color': '',
#   'flair_color': '',
#   'flair_group_id': 294,
#   'badges_granted': [],
#   'version': 4,
#   'can_edit': False,
#   'can_delete': False,
#   'can_recover': False,
#   'can_see_hidden_post': False,
#   'can_wiki': False,
#   'read': False,
#   'user_title': '',
#   'bookmarked': False,
#   'actions_summary': [{'id': 2, 'can_act': True},
#    {'id': 6, 'can_act': True},
#    {'id': 3, 'can_act': True},
#    {'id': 4, 'can_act': True},
#    {'id': 8, 'can_act': True},
#    {'id': 10, 'can_act': True},
#    {'id': 7, 'can_act': True}],
#   'moderator': False,
#   'admin': False,
#   'staff': False,
#   'user_id': 30376,
#   'hidden': False,
#   'trust_level': 1,
#   'deleted_at': None,
#   'user_deleted': False,
#   'edit_reason': None,
#   'can_view_edit_history': True,
#   'wiki': False,
#   'post_url': '/t/queries-regarding-end-term-exam-solutions/172707/9',
#   'user_cakedate': '2024-06-02',
#   'user_birthdate': '1904-09-28',
#   'reactions': [],
#   'current_user_reaction': None,
#   'reaction_users_count': 0,
#   'current_user_used_main_reaction': False,
#   'can_accept_answer': False,
#   'can_unaccept_answer': False,
#   'accepted_answer': False,
#   'topic_accepted_answer': None},
#  {'id': 620540,
#   'name': 'Swati Kapoor',
#   'username': 'swatikap',
#   'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/swatikap/{size}/66760_2.png',
#   'created_at': '2025-04-17T04:20:13.544Z',
#   'cooked': '<p>Hi,<br>\nFrom where are you checking the transcripts? I’m not able to see the answer transcripts in the score checker app.<br>\n<div class="lightbox-wrapper"><a class="lightbox" href="https://europe1.discourse-cdn.com/flex013/uploads/iitm/original/3X/3/d/3d54127deb9243fce2a75dace8f4b52f14f9057f.png" data-download-href="/uploads/short-url/8KxftzhVAR7hdIl6XyT5lEFAL6v.png?dl=1" title="image" rel="noopener nofollow ugc"><img src="https://europe1.discourse-cdn.com/flex013/uploads/iitm/optimized/3X/3/d/3d54127deb9243fce2a75dace8f4b52f14f9057f_2_690x226.png" alt="image" data-base62-sha1="8KxftzhVAR7hdIl6XyT5lEFAL6v" width="690" height="226" srcset="https://europe1.discourse-cdn.com/flex013/uploads/iitm/optimized/3X/3/d/3d54127deb9243fce2a75dace8f4b52f14f9057f_2_690x226.png, https://europe1.discourse-cdn.com/flex013/uploads/iitm/optimized/3X/3/d/3d54127deb9243fce2a75dace8f4b52f14f9057f_2_1035x339.png 1.5x, https://europe1.discourse-cdn.com/flex013/uploads/iitm/optimized/3X/3/d/3d54127deb9243fce2a75dace8f4b52f14f9057f_2_1380x452.png 2x" data-dominant-color="CBD2D6"><div class="meta"><svg class="fa d-icon d-icon-far-image svg-icon" aria-hidden="true"><use href="#far-image"></use></svg><span class="filename">image</span><span class="informations">1891×622 31.7 KB</span><svg class="fa d-icon d-icon-discourse-expand svg-icon" aria-hidden="true"><use href="#discourse-expand"></use></svg></div></a></div></p>',
#   'post_number': 10,
#   'post_type': 1,
#   'posts_count': 16,
#   'updated_at': '2025-04-17T04:20:13.544Z',
#   'reply_count': 1,
#   'reply_to_post_number': None,
#   'quote_count': 0,
#   'incoming_link_count': 0,
#   'reads': 48,
#   'readers_count': 47,
#   'score': 14.4,
#   'yours': False,
#   'topic_id': 172707,
#   'topic_slug': 'queries-regarding-end-term-exam-solutions',
#   'display_username': 'Swati Kapoor',
#   'primary_group_name': 'ds-students',
#   'flair_name': 'ds-students',
#   'flair_url': None,
#   'flair_bg_color': '',
#   'flair_color': '',
#   'flair_group_id': 294,
#   'badges_granted': [],
#   'version': 1,
#   'can_edit': False,
#   'can_delete': False,
#   'can_recover': False,
#   'can_see_hidden_post': False,
#   'can_wiki': False,
#   'read': False,
#   'user_title': None,
#   'bookmarked': False,
#   'actions_summary': [{'id': 2, 'can_act': True},
#    {'id': 6, 'can_act': True},
#    {'id': 3, 'can_act': True},
#    {'id': 4, 'can_act': True},
#    {'id': 8, 'can_act': True},
#    {'id': 10, 'can_act': True},
#    {'id': 7, 'can_act': True}],
#   'moderator': False,
#   'admin': False,
#   'staff': False,
#   'user_id': 24244,
#   'hidden': False,
#   'trust_level': 1,
#   'deleted_at': None,
#   'user_deleted': False,
#   'edit_reason': None,
#   'can_view_edit_history': True,
#   'wiki': False,
#   'post_url': '/t/queries-regarding-end-term-exam-solutions/172707/10',
#   'user_cakedate': '2023-10-16',
#   'reactions': [],
#   'current_user_reaction': None,
#   'reaction_users_count': 0,
#   'current_user_used_main_reaction': False,
#   'can_accept_answer': False,
#   'can_unaccept_answer': False,
#   'accepted_answer': False,
#   'topic_accepted_answer': None},
#  {'id': 620544,
#   'name': 'Shambhavi Verma',
#   'username': '24f2003130',
#   'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/24f2003130/{size}/132501_2.png',
#   'created_at': '2025-04-17T04:22:31.946Z',
#   'cooked': '<p>Click on the eye button …then you will be able to view your transcript</p>',
#   'post_number': 11,
#   'post_type': 1,
#   'posts_count': 16,
#   'updated_at': '2025-04-17T04:22:31.946Z',
#   'reply_count': 1,
#   'reply_to_post_number': 10,
#   'quote_count': 0,
#   'incoming_link_count': 0,
#   'reads': 50,
#   'readers_count': 49,
#   'score': 14.8,
#   'yours': False,
#   'topic_id': 172707,
#   'topic_slug': 'queries-regarding-end-term-exam-solutions',
#   'display_username': 'Shambhavi Verma',
#   'primary_group_name': 'ds-students',
#   'flair_name': 'ds-students',
#   'flair_url': None,
#   'flair_bg_color': '',
#   'flair_color': '',
#   'flair_group_id': 294,
#   'badges_granted': [],
#   'version': 1,
#   'can_edit': False,
#   'can_delete': False,
#   'can_recover': False,
#   'can_see_hidden_post': False,
#   'can_wiki': False,
#   'read': False,
#   'user_title': '',
#   'reply_to_user': {'id': 24244,
#    'username': 'swatikap',
#    'name': 'Swati Kapoor',
#    'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/swatikap/{size}/66760_2.png'},
#   'bookmarked': False,
#   'actions_summary': [{'id': 2, 'can_act': True},
#    {'id': 6, 'can_act': True},
#    {'id': 3, 'can_act': True},
#    {'id': 4, 'can_act': True},
#    {'id': 8, 'can_act': True},
#    {'id': 10, 'can_act': True},
#    {'id': 7, 'can_act': True}],
#   'moderator': False,
#   'admin': False,
#   'staff': False,
#   'user_id': 30376,
#   'hidden': False,
#   'trust_level': 1,
#   'deleted_at': None,
#   'user_deleted': False,
#   'edit_reason': None,
#   'can_view_edit_history': True,
#   'wiki': False,
#   'post_url': '/t/queries-regarding-end-term-exam-solutions/172707/11',
#   'user_cakedate': '2024-06-02',
#   'user_birthdate': '1904-09-28',
#   'reactions': [],
#   'current_user_reaction': None,
#   'reaction_users_count': 0,
#   'current_user_used_main_reaction': False,
#   'can_accept_answer': False,
#   'can_unaccept_answer': False,
#   'accepted_answer': False,
#   'topic_accepted_answer': None},
#  {'id': 620546,
#   'name': 'Swati Kapoor',
#   'username': 'swatikap',
#   'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/swatikap/{size}/66760_2.png',
#   'created_at': '2025-04-17T04:25:22.034Z',
#   'cooked': '<p>Thanks for the reply, but I only see the question id’s and answer id’s, not able to find the transcripts.<br>\n<div class="lightbox-wrapper"><a class="lightbox" href="https://europe1.discourse-cdn.com/flex013/uploads/iitm/original/3X/f/7/f7adba30daf6dbdfda4884a7b821a593557a466a.png" data-download-href="/uploads/short-url/zl48WsOV7M3b9v0o3ZveMo6b6ye.png?dl=1" title="image" rel="noopener nofollow ugc"><img src="https://europe1.discourse-cdn.com/flex013/uploads/iitm/optimized/3X/f/7/f7adba30daf6dbdfda4884a7b821a593557a466a_2_690x341.png" alt="image" data-base62-sha1="zl48WsOV7M3b9v0o3ZveMo6b6ye" width="690" height="341" srcset="https://europe1.discourse-cdn.com/flex013/uploads/iitm/optimized/3X/f/7/f7adba30daf6dbdfda4884a7b821a593557a466a_2_690x341.png, https://europe1.discourse-cdn.com/flex013/uploads/iitm/optimized/3X/f/7/f7adba30daf6dbdfda4884a7b821a593557a466a_2_1035x511.png 1.5x, https://europe1.discourse-cdn.com/flex013/uploads/iitm/optimized/3X/f/7/f7adba30daf6dbdfda4884a7b821a593557a466a_2_1380x682.png 2x" data-dominant-color="E0E3CC"><div class="meta"><svg class="fa d-icon d-icon-far-image svg-icon" aria-hidden="true"><use href="#far-image"></use></svg><span class="filename">image</span><span class="informations">1867×923 94.1 KB</span><svg class="fa d-icon d-icon-discourse-expand svg-icon" aria-hidden="true"><use href="#discourse-expand"></use></svg></div></a></div></p>',
#   'post_number': 12,
#   'post_type': 1,
#   'posts_count': 16,
#   'updated_at': '2025-04-17T04:25:22.034Z',
#   'reply_count': 1,
#   'reply_to_post_number': 11,
#   'quote_count': 0,
#   'incoming_link_count': 0,
#   'reads': 47,
#   'readers_count': 46,
#   'score': 14.2,
#   'yours': False,
#   'topic_id': 172707,
#   'topic_slug': 'queries-regarding-end-term-exam-solutions',
#   'display_username': 'Swati Kapoor',
#   'primary_group_name': 'ds-students',
#   'flair_name': 'ds-students',
#   'flair_url': None,
#   'flair_bg_color': '',
#   'flair_color': '',
#   'flair_group_id': 294,
#   'badges_granted': [],
#   'version': 1,
#   'can_edit': False,
#   'can_delete': False,
#   'can_recover': False,
#   'can_see_hidden_post': False,
#   'can_wiki': False,
#   'read': False,
#   'user_title': None,
#   'reply_to_user': {'id': 30376,
#    'username': '24f2003130',
#    'name': 'Shambhavi Verma',
#    'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/24f2003130/{size}/132501_2.png'},
#   'bookmarked': False,
#   'actions_summary': [{'id': 2, 'can_act': True},
#    {'id': 6, 'can_act': True},
#    {'id': 3, 'can_act': True},
#    {'id': 4, 'can_act': True},
#    {'id': 8, 'can_act': True},
#    {'id': 10, 'can_act': True},
#    {'id': 7, 'can_act': True}],
#   'moderator': False,
#   'admin': False,
#   'staff': False,
#   'user_id': 24244,
#   'hidden': False,
#   'trust_level': 1,
#   'deleted_at': None,
#   'user_deleted': False,
#   'edit_reason': None,
#   'can_view_edit_history': True,
#   'wiki': False,
#   'post_url': '/t/queries-regarding-end-term-exam-solutions/172707/12',
#   'user_cakedate': '2023-10-16',
#   'reactions': [],
#   'current_user_reaction': None,
#   'reaction_users_count': 0,
#   'current_user_used_main_reaction': False,
#   'can_accept_answer': False,
#   'can_unaccept_answer': False,
#   'accepted_answer': False,
#   'topic_accepted_answer': None},
#  {'id': 620547,
#   'name': 'Shambhavi Verma',
#   'username': '24f2003130',
#   'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/24f2003130/{size}/132501_2.png',
#   'created_at': '2025-04-17T04:28:25.475Z',
#   'cooked': '<p>It seems that the option to download the answer key has been removed. However, you could consider reaching out to someone in the group or checking the dashboard for  solution pdf of question paper. You can then match the questions in order, even if the IDs don’t align exactly—it should still give you a general idea. From there, you can proceed accordingly.</p>',
#   'post_number': 13,
#   'post_type': 1,
#   'posts_count': 16,
#   'updated_at': '2025-04-17T04:28:25.475Z',
#   'reply_count': 0,
#   'reply_to_post_number': 12,
#   'quote_count': 0,
#   'incoming_link_count': 0,
#   'reads': 46,
#   'readers_count': 45,
#   'score': 24.2,
#   'yours': False,
#   'topic_id': 172707,
#   'topic_slug': 'queries-regarding-end-term-exam-solutions',
#   'display_username': 'Shambhavi Verma',
#   'primary_group_name': 'ds-students',
#   'flair_name': 'ds-students',
#   'flair_url': None,
#   'flair_bg_color': '',
#   'flair_color': '',
#   'flair_group_id': 294,
#   'badges_granted': [],
#   'version': 1,
#   'can_edit': False,
#   'can_delete': False,
#   'can_recover': False,
#   'can_see_hidden_post': False,
#   'can_wiki': False,
#   'read': False,
#   'user_title': '',
#   'reply_to_user': {'id': 24244,
#    'username': 'swatikap',
#    'name': 'Swati Kapoor',
#    'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/swatikap/{size}/66760_2.png'},
#   'bookmarked': False,
#   'actions_summary': [{'id': 2, 'count': 1, 'can_act': True},
#    {'id': 6, 'can_act': True},
#    {'id': 3, 'can_act': True},
#    {'id': 4, 'can_act': True},
#    {'id': 8, 'can_act': True},
#    {'id': 10, 'can_act': True},
#    {'id': 7, 'can_act': True}],
#   'moderator': False,
#   'admin': False,
#   'staff': False,
#   'user_id': 30376,
#   'hidden': False,
#   'trust_level': 1,
#   'deleted_at': None,
#   'user_deleted': False,
#   'edit_reason': None,
#   'can_view_edit_history': True,
#   'wiki': False,
#   'post_url': '/t/queries-regarding-end-term-exam-solutions/172707/13',
#   'user_cakedate': '2024-06-02',
#   'user_birthdate': '1904-09-28',
#   'reactions': [{'id': 'heart', 'type': 'emoji', 'count': 1}],
#   'current_user_reaction': None,
#   'reaction_users_count': 1,
#   'current_user_used_main_reaction': False,
#   'can_accept_answer': False,
#   'can_unaccept_answer': False,
#   'accepted_answer': False,
#   'topic_accepted_answer': None},
#  {'id': 621044,
#   'name': 'Shivaditya Bhattacharya',
#   'username': '22f3000819',
#   'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/22f3000819/{size}/66738_2.png',
#   'created_at': '2025-04-17T18:05:30.227Z',
#   'cooked': '<p><a class="mention" href="/u/iamprasna">@iamprasna</a> <a class="mention" href="/u/carlton">@carlton</a> Please look into it once. According to point 3 of <a class="mention" href="/u/iamprasna">@iamprasna</a>’s post, I should get full credit for that question and it will take me to a perfect 100 score in ET from the current 97. I brought this into attention before the scores were pushed to the dashboard.</p>\n<p>Regards,<br>\nShivaditya</p>',
#   'post_number': 14,
#   'post_type': 1,
#   'posts_count': 16,
#   'updated_at': '2025-04-17T18:05:30.227Z',
#   'reply_count': 0,
#   'reply_to_post_number': 6,
#   'quote_count': 0,
#   'incoming_link_count': 1,
#   'reads': 39,
#   'readers_count': 38,
#   'score': 12.8,
#   'yours': False,
#   'topic_id': 172707,
#   'topic_slug': 'queries-regarding-end-term-exam-solutions',
#   'display_username': 'Shivaditya Bhattacharya',
#   'primary_group_name': 'ds-students',
#   'flair_name': 'ds-students',
#   'flair_url': None,
#   'flair_bg_color': '',
#   'flair_color': '',
#   'flair_group_id': 294,
#   'badges_granted': [],
#   'version': 1,
#   'can_edit': False,
#   'can_delete': False,
#   'can_recover': False,
#   'can_see_hidden_post': False,
#   'can_wiki': False,
#   'read': False,
#   'user_title': '',
#   'reply_to_user': {'id': 16002,
#    'username': '22f3000819',
#    'name': 'Shivaditya Bhattacharya',
#    'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/22f3000819/{size}/66738_2.png'},
#   'bookmarked': False,
#   'actions_summary': [{'id': 2, 'can_act': True},
#    {'id': 6, 'can_act': True},
#    {'id': 3, 'can_act': True},
#    {'id': 4, 'can_act': True},
#    {'id': 8, 'can_act': True},
#    {'id': 10, 'can_act': True},
#    {'id': 7, 'can_act': True}],
#   'moderator': False,
#   'admin': False,
#   'staff': False,
#   'user_id': 16002,
#   'hidden': False,
#   'trust_level': 1,
#   'deleted_at': None,
#   'user_deleted': False,
#   'edit_reason': None,
#   'can_view_edit_history': True,
#   'wiki': False,
#   'post_url': '/t/queries-regarding-end-term-exam-solutions/172707/14',
#   'user_cakedate': '2023-01-25',
#   'user_birthdate': '1904-03-07',
#   'reactions': [],
#   'current_user_reaction': None,
#   'reaction_users_count': 0,
#   'current_user_used_main_reaction': False,
#   'can_accept_answer': False,
#   'can_unaccept_answer': False,
#   'accepted_answer': False,
#   'topic_accepted_answer': None},
#  {'id': 621914,
#   'name': 'Prasanna',
#   'username': 'iamprasna',
#   'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/iamprasna/{size}/13977_2.png',
#   'created_at': '2025-04-21T10:46:35.817Z',
#   'cooked': '<p>The correction has been done to the following question for both the FN and AN sessions. You must be able to see the change in scores shortly</p>\n<ol>\n<li><strong>Entries with 404 status code</strong><br>\nAlthough the instructions did not explicitly state that filters applied for status code 404, we acknowledge this ambiguity. Full credit will be awarded for both option 1 and option 4.</li>\n</ol>',
#   'post_number': 15,
#   'post_type': 1,
#   'posts_count': 16,
#   'updated_at': '2025-04-21T10:46:35.817Z',
#   'reply_count': 1,
#   'reply_to_post_number': None,
#   'quote_count': 0,
#   'incoming_link_count': 0,
#   'reads': 32,
#   'readers_count': 31,
#   'score': 56.2,
#   'yours': False,
#   'topic_id': 172707,
#   'topic_slug': 'queries-regarding-end-term-exam-solutions',
#   'display_username': 'Prasanna',
#   'primary_group_name': 'course_support',
#   'flair_name': 'course_support',
#   'flair_url': 'scale-balanced',
#   'flair_bg_color': '0040ff',
#   'flair_color': '1affc6',
#   'flair_group_id': 41,
#   'badges_granted': [],
#   'version': 1,
#   'can_edit': False,
#   'can_delete': False,
#   'can_recover': False,
#   'can_see_hidden_post': False,
#   'can_wiki': False,
#   'read': False,
#   'user_title': 'Course_Team',
#   'title_is_group': True,
#   'bookmarked': False,
#   'actions_summary': [{'id': 2, 'count': 3, 'can_act': True},
#    {'id': 6, 'can_act': True},
#    {'id': 3, 'can_act': True},
#    {'id': 4, 'can_act': True},
#    {'id': 8, 'can_act': True},
#    {'id': 10, 'can_act': True},
#    {'id': 7, 'can_act': True}],
#   'moderator': False,
#   'admin': False,
#   'staff': False,
#   'user_id': 9398,
#   'hidden': False,
#   'trust_level': 4,
#   'deleted_at': None,
#   'user_deleted': False,
#   'edit_reason': None,
#   'can_view_edit_history': True,
#   'wiki': False,
#   'post_url': '/t/queries-regarding-end-term-exam-solutions/172707/15',
#   'user_cakedate': '2022-01-03',
#   'reactions': [{'id': 'heart', 'type': 'emoji', 'count': 3}],
#   'current_user_reaction': None,
#   'reaction_users_count': 3,
#   'current_user_used_main_reaction': False,
#   'can_accept_answer': False,
#   'can_unaccept_answer': False,
#   'accepted_answer': False,
#   'topic_accepted_answer': None},
#  {'id': 621957,
#   'name': 'Shambhavi Verma',
#   'username': '24f2003130',
#   'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/24f2003130/{size}/132501_2.png',
#   'created_at': '2025-04-21T13:51:30.076Z',
#   'cooked': '<p>Thank you sir for acknowledging our requests and resolving the error</p>',
#   'post_number': 16,
#   'post_type': 1,
#   'posts_count': 16,
#   'updated_at': '2025-04-21T13:51:30.076Z',
#   'reply_count': 0,
#   'reply_to_post_number': 15,
#   'quote_count': 0,
#   'incoming_link_count': 0,
#   'reads': 30,
#   'readers_count': 29,
#   'score': 5.8,
#   'yours': False,
#   'topic_id': 172707,
#   'topic_slug': 'queries-regarding-end-term-exam-solutions',
#   'display_username': 'Shambhavi Verma',
#   'primary_group_name': 'ds-students',
#   'flair_name': 'ds-students',
#   'flair_url': None,
#   'flair_bg_color': '',
#   'flair_color': '',
#   'flair_group_id': 294,
#   'badges_granted': [],
#   'version': 1,
#   'can_edit': False,
#   'can_delete': False,
#   'can_recover': False,
#   'can_see_hidden_post': False,
#   'can_wiki': False,
#   'read': False,
#   'user_title': '',
#   'reply_to_user': {'id': 9398,
#    'username': 'iamprasna',
#    'name': 'Prasanna',
#    'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/iamprasna/{size}/13977_2.png'},
#   'bookmarked': False,
#   'actions_summary': [{'id': 2, 'can_act': True},
#    {'id': 6, 'can_act': True},
#    {'id': 3, 'can_act': True},
#    {'id': 4, 'can_act': True},
#    {'id': 8, 'can_act': True},
#    {'id': 10, 'can_act': True},
#    {'id': 7, 'can_act': True}],
#   'moderator': False,
#   'admin': False,
#   'staff': False,
#   'user_id': 30376,
#   'hidden': False,
#   'trust_level': 1,
#   'deleted_at': None,
#   'user_deleted': False,
#   'edit_reason': None,
#   'can_view_edit_history': True,
#   'wiki': False,
#   'post_url': '/t/queries-regarding-end-term-exam-solutions/172707/16',
#   'user_cakedate': '2024-06-02',
#   'user_birthdate': '1904-09-28',
#   'reactions': [],
#   'current_user_reaction': None,
#   'reaction_users_count': 0,
#   'current_user_used_main_reaction': False,
#   'can_accept_answer': False,
#   'can_unaccept_answer': False,
#   'accepted_answer': False,
#   'topic_accepted_answer': None}]

# %%
for post in posts:
    post_id = post.get('id')
    post_number = post.get('post_number')
    author = post.get('username', '')
    created_at = post.get('created_at', '')
    likes = post.get('like_count', 0)
    html_content = post.get('cooked', '')

# %%
html_content
# Out:
# '<p>Yes you should do tds after mlp only it really help you alot trust me</p>'

# %%
from pathlib import Path
import numpy as np
from tqdm import tqdm
from embed import get_chunks, get_embeddings
from config import GEMINI_API_KEY
from extract_text import extract_text_from_markdown
import asyncio
import signal
import json, sys, os

# %%
files = [*Path("raw-data/Discourse-data").glob("*.json")]
all_chunks = []
all_embeddings = []
all_original_urls = []
total_chunks = 0
file_chunks = {}
file_urls = {}

def read_json_file(file):
    with open(file, 'r', encoding='utf-8') as f:
        return json.load(f)
# First pass: extract content and count chunks
for file_path in files:
    data = read_json_file((file_path))
    content, original_url = extract_text_from_markdown(file_path)
    
    print(content)
    # chunks = get_chunks(content)
    # file_chunks[file_path] = chunks
    # file_urls[file_path] = original_url
    # total_chunks += len(chunks)
    # print(f"File: {file_path.name}, Chunks: {len(chunks)}")
    break

# print(f"Total chunks created: {total_chunks}")


# start_file_index = 0
# start_chunk_index = 0

# # Find the starting file and chunk position
# file_list = list(file_chunks.items())
# for i, (file_path, chunks) in enumerate(file_list):
#     if chunks_to_skip >= len(chunks):
#         chunks_to_skip -= len(chunks)
#     else:
#         start_file_index = i
#         start_chunk_index = chunks_to_skip
#         break

# processed_count = existing_count
# # Second pass: process chunks starting from the correct position
# with tqdm(total=total_chunks, initial=existing_count, desc="Processing Chunks") as pbar:
#     for i in range(start_file_index, len(file_list)):
#         file_path, chunks = file_list[i]
#         original_url = file_urls[file_path]
        
#         # Start from the correct chunk index for the first file, 0 for others
#         chunk_start = start_chunk_index if i == start_file_index else 0
        
#         for j in range(chunk_start, len(chunks)):
#             chunk = chunks[j]
#             try:
#                 embedding = await get_embeddings(chunk, api_key=GEMINI_API_KEY)
#                 all_chunks.append([chunk])  # Simplified - removed unnecessary list wrapping
#                 all_embeddings.append([embedding])  # Simplified
#                 all_original_urls.append([original_url])  # Simplified
#                 processed_count += 1
#                 pbar.set_postfix({"file": file_path.name, "chunk": processed_count})
#                 print(f'{chunk} is created of url {original_url} and first few embeddings are: {embedding[:6]}')
#             except Exception as e:
#                 print(f"Error processing chunk in {file_path}: {e}")
#             finally:
#                 pbar.update(1)

# %%
import requests
import base64
from io import BytesIO
from PIL import Image

# %%
def image_url_to_base64(image_url, format_hint=None):
    response = requests.get(image_url)
    response.raise_for_status()  # Ensure the request was successful
    img = Image.open(BytesIO(response.content))
    buffered = BytesIO()
    # Use the format_hint if provided, else use the format from the image
    img_format = format_hint if format_hint else img.format
    img.save(buffered, format=img_format)
    img_bytes = buffered.getvalue()
    base64_str = base64.b64encode(img_bytes).decode('utf-8')
    return base64_str

# Example usage:
url = "https://europe1.discourse-cdn.com/flex013/uploads/iitm/original/3X/f/8/f8af7c6e2fe001c8bf000605b52c903e1b0e6fe1.png"
b64_img = image_url_to_base64(url)
print(b64_img[:100])  # Print the first 100 characters of the base64 string
# Out:
# iVBORw0KGgoAAAANSUhEUgAABRAAAACeCAMAAAB9wNa5AAACcFBMVEUhJSne4ubSsn6n1uYhJX5kJSne1rVkstqJxObexJ2Jmsi6

# %%
import base64
# from google.generativeai import Client, types
from google.genai import Client, types

# %%
def describe_base64_image(base64_image, api_key):
    # Decode the base64 string to bytes
    image_bytes = base64.b64decode(base64_image)
    
    # Initialize the Gemini API client
    client = Client(api_key=api_key)
    
    # Generate the description
    response = client.models.generate_content(
        model='gemini-2.0-flash',
        contents=[
            types.Part.from_bytes(
                data=image_bytes,
                mime_type='image/jpeg',  # or 'image/png' if your image is PNG
            ),
            """Perform Optical Character Recognition (OCR) on the provided image to extract all readable text accurately. Follow these steps:

            1. Analyze the input image or document containing text
            2. Extract ALL visible text while preserving formatting, line breaks, and spatial relationships where possible
            3. Identify and transcribe any error messages, menu options, button labels, dialog boxes, and interface elements
            4. Verify the accuracy of recognized characters, especially for technical terms, error codes, and numerical values
            5. Present the extracted text in a clear, structured format that maintains the original context

            ## Output Requirements:
            - Return extracted text as plain, continuous text with natural spacing
            - Preserve original line breaks and formatting structure
            - Handle various fonts, sizes, and orientations of text
            - Be robust against noise, distortion, and low image quality
            - Flag any unclear or illegible parts with [UNCLEAR] markers
            - Do not include additional commentary or metadata
            """
        ]
    )
    return response

description = describe_base64_image(b64_img, GEMINI_API_KEY)

# %%
print(description.text)
# Out:
# 16 Move and rename files (0.5 marks)
# Download q-move-rename-files.zip and extract it. Use mv to move all files under folders into an empty folder. Then rename all files replacing each digit with the next (i.e. a19b.txt
# becomes a20b.txt)
# What does running grep .* | LC_ALL=C sort | sha256sum in bash on that folder show?

# %%
# def image_to_b64(img_path):
#     with open(img_path, 'rb') as f:
#         binary_data = f.read()
#         encoded_img = base64.b64encode(binary_data).decode()
#     return encoded_img

# %%
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 image_to_b64("https://europe1.discourse-cdn.com/flex013/uploads/iitm/original/3X/f/8/f8af7c6e2fe001c8bf000605b52c903e1b0e6fe1.png")
#
# Cell In[9], line 2, in image_to_b64(img_path)
#       1 def image_to_b64(img_path):
# ----> 2     with open(img_path, 'rb') as f:
#       3         binary_data = f.read()
#       4         encoded_img = base64.b64encode(binary_data).decode()
#
# File d:\GyanPrakashKushwaha\TDS\On-My-Own\venv\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# OSError: [Errno 22] Invalid argument: 'https://europe1.discourse-cdn.com/flex013/uploads/iitm/original/3X/f/8/f8af7c6e2fe001c8bf000605b52c903e1b0e6fe1.png'

# %%
for i in range(10):
    if i == 2:
        continue
    print(i)
# Out:
# 0
# 1
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
files = [*Path("raw-data/Discourse-data").glob("*.json")]

# %% [markdown]
# # DEBUGGING CODE........

# %%
from pathlib import Path
import numpy as np
from tqdm import tqdm
from embed import get_chunks, get_embeddings
from config import GEMINI_API_KEY
from extract_text import extract_text_from_markdown, clean_html
import asyncio
import signal
import json, sys, os
import re
import base64
# from google.generativeai import Client, types
from google.genai import Client, types
import requests
import base64
from io import BytesIO
from PIL import Image
import urllib

def image_url_to_base64(image_url, format_hint=None):
    headers = {
        "User-Agent": (
            "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
            "AppleWebKit/537.36 (KHTML, like Gecko) "
            "Chrome/129.0.0.0 Safari/537.36"
        ),
        "Referer": "https://europe1.discourse-cdn.com/"
    }
    try:
        response = requests.get(image_url, headers=headers)
        response.raise_for_status()
        img_bytes = response.content
        base64_str = base64.b64encode(img_bytes).decode()
        return base64_str
    except requests.exceptions.HTTPError as e:
        print(f"HTTP error for {image_url}: {e}")
        return None
    except Exception as e:
        print(f"Other error for {image_url}: {e}")
        return None


def describe_base64_image(base64_image, api_key):
    # Decode the base64 string to bytes
    image_bytes = base64.b64decode(base64_image)
    
    # Initialize the Gemini API client
    client = Client(api_key=api_key)
    
    # Generate the description
    response = client.models.generate_content(
        model='gemini-2.0-flash',
        contents=[
            types.Part.from_bytes(
                data=image_bytes,
                mime_type='image/jpeg',  # or 'image/png' if your image is PNG
            ),
            """Perform Optical Character Recognition (OCR) on the provided image to extract all readable text accurately. Follow these steps:

            1. Analyze the input image or document containing text
            2. Extract ALL visible text while preserving formatting, line breaks, and spatial relationships where possible
            3. Identify and transcribe any error messages, menu options, button labels, dialog boxes, and interface elements
            4. Verify the accuracy of recognized characters, especially for technical terms, error codes, and numerical values
            5. Present the extracted text in a clear, structured format that maintains the original context

            ## Output Requirements:
            - Return extracted text as plain, continuous text with natural spacing
            - Preserve original line breaks and formatting structure
            - Handle various fonts, sizes, and orientations of text
            - Be robust against noise, distortion, and low image quality
            - Flag any unclear or illegible parts with [UNCLEAR] markers
            - Do not include additional commentary or metadata
            """
        ]
    )
    return response.text



def extract_europe1_urls(text):
    # Regex pattern to find URLs starting with 'https://europe1'
    pattern = r'https://europe1[^"\s]+'
    urls = re.findall(pattern, text)
    return urls

def read_json_file(file):
    with open(file, 'r', encoding='utf-8') as f:
        return json.load(f)


async def process_save_discourse():
    files = [*Path("raw-data/Discourse-data").glob("*.json")]
    all_chunks = []
    all_embeddings = []
    all_original_urls = []
    c = 0

    for file_path in files:
        data = read_json_file(file_path)
        posts = data.get('post_stream', {}).get('posts', [])
        topic_id = data.get('id')
        topic_slug = data.get('slug', '')
        
        complete_post = ''
        for post in posts:
            post_number = post.get('post_number')
            content = post.get('cooked', '')
            question_img_url = extract_europe1_urls(content) if extract_europe1_urls(content) else None
            clean_content = clean_html(content)
            if question_img_url:
                print('================================================== \n IMG FOUND \n =============================')
                url = question_img_url[0]
            #     dummy_Des = '---------This is a dummy description for the image.----------'
            #     complete_post += dummy_Des

            #     b64IMG = image_url_to_base64(url)
            #     if b64IMG:
            #         try:
            #             description = describe_base64_image(b64IMG, GEMINI_API_KEY)
            #             print(description)
            #             complete_post += description
            #         except Exception as e:
            #             print(f"Error describing image {url}: {e}")
            #     else:
            #         print(f"Skipping image {url} due to download error.")
                
            # complete_post += clean_content

        # print(complete_post, '\n=========================================================\n=========================================================')
        chunks = get_chunks(complete_post)
        # print(f'======================= Complete post ======================= \n {complete_post} \n\n')
        # print(f'======================= Chunks ======================= \n\n')
        # print(get_chunks(complete_post))
        topic_url = f"https://discourse.onlinedegree.iitm.ac.in/t/{topic_slug}/{topic_id}"
        # print(f'========= Topic URL ======================= \n {topic_url} \n\n')
        # for chunk in chunks:
        #     all_chunks.append(chunk)
        #     all_original_urls.append(topic_url)
        #     # create embeddings for chunks
        #     try:
        #         embedding = await get_embeddings(chunk, GEMINI_API_KEY)
        #         all_embeddings.append(embedding)
        #         print(f'embedding is being generated for {file_path.name} the chunk is {chunk[:50]}... \n Embeddings {embedding[:5]} and url is {url}')
        #     except Exception as e:
        #         print(f"Error getting embedding for chunk: {e}")

        c+= 1
        if c == 10:
            break
    
    


    
if __name__ == "__main__":
    asyncio.run(process_save_discourse())
    # print("Processing complete. Embeddings saved to 'markdown_embeddings.npz'.")  # Fixed syntax
