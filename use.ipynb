# %%
import numpy as np

# %%
data = np.load('markdown_embeddings.npz', allow_pickle=True)

# %%
data
# Out:
# NpzFile 'markdown_embeddings.npz' with keys: chunks, embeddings, original_urls

# %%
len(data['original_urls'])
# Out:
# 17

# %%
from config import GEMINI_API_KEY
from google import genai

# %%
client = genai.Client(api_key='AIzaSyAsWaYnR14eCSvPDSy78AFBZAFSECxm8w8')

# %%
response = client.models.embed_content(
                model='gemini-embedding-exp-03-07',
                contents=["Development Tools NOTE : The tools in this module are PRE-REQUISITES for the course. You would have used most of these before. If most of this is new to you, please take this course later. Some tools are fundamental to data science because they are industry standards and widely used by data science professionals. Mastering these tools will align you with current best practices and making you more adaptable in a fast-evolving industry. The tools we cover here are not just popular, they’re the core technology behind most of today’s data science and software development."]
            )

# %%
response
# Out:
# EmbedContentResponse(embeddings=[ContentEmbedding(values=[0.0039222273, 0.0087520955, -0.0065032397, -0.044435333, 0.012589616, 0.032592773, 0.013753255, -0.0049841064, 0.0010558376, -0.008490999, -0.030932503, -0.020973764, 0.025540557, 0.019598544, 0.12997827, 0.0009875114, -0.004475424, -0.012211627, 0.02634175, -0.018094426, -0.005044977, 0.016982133, -0.017249638, -0.02897581, 0.02644723, -0.031068629, 0.0074642305, -0.005448184, 0.046699002, -0.0027329512, -0.014549907, 0.002545577, 0.0071367333, 0.03945758, 0.0011808169, 0.027469618, -0.0033627169, -0.008082436, 0.026695013, 0.010332906, -0.012630907, -0.00396128, -0.0020128402, -0.032113757, 0.0117953895, 0.016779387, -0.003514428, 0.0061493735, -0.0125778355, 0.0138864, -0.0029460953, -0.006751054, -0.026570043, -0.16829786, 0.0040568374, -0.0015059083, -0.010538709, 0.015231082, -0.0027721513, -0.0063215555, -0.012528604, 0.005178266, -0.045855317, -0.003747182, 0.010028187, -0.0072063496, 0.026050985, -0.022581168, 0.00016
# ...

# %%
import json

# %%
with open("emergency_save.json", "r", encoding = 'utf-8') as f:
    data = json.load(f)

# %%
len(data['embeddings'])
# Out:
# 89

# %%
len(data['embeddings'][79])
# Out:
# 1

# %%
len(data['embeddings'][1][0])
# Out:
# 3072

# %%
for i in range(len(data['embeddings'])):
    if not data['embeddings'][i][0]:
        print(f"Error at index {i}: {len(data['embeddings'][i])} dimensions")
        
    # if len(data['embeddings'][i][0]) == 1:
    #     print(f"Error at index {i}: {len(data['embeddings'][i])} dimensions")
# Out:
# Error at index 68: 1 dimensions
# Error at index 69: 1 dimensions
# Error at index 71: 1 dimensions
# Error at index 78: 1 dimensions
# Error at index 79: 1 dimensions
# Error at index 80: 1 dimensions
# Error at index 81: 1 dimensions
# Error at index 82: 1 dimensions
# Error at index 83: 1 dimensions
# Error at index 84: 1 dimensions
# Error at index 85: 1 dimensions
# Error at index 86: 1 dimensions
# Error at index 87: 1 dimensions
# Error at index 88: 1 dimensions

# %%
with open("emergency_save_me.json", "r", encoding="utf-8") as f:
    saved_data = json.load(f)
    all_chunks = saved_data["chunks"]
    all_embeddings = saved_data["embeddings"] 
    all_original_urls = saved_data["original_urls"]
    
    # Count only valid (non-null) embeddings
    valid_count = 0
    for i, embedding in enumerate(all_embeddings):
        if embedding[0] is not None and embedding[0] != [] and len(str(embedding).strip()) > 0:
            valid_count += 1
        else:
            # Remove invalid entries
            break

# %%
valid_count
# Out:
# 68

# %%
# all_original_urls
# Out:
# [['https://tds.s-anand.net/#/development-tools?id=development-tools'],
#  ['https://tds.s-anand.net/#/deployment-tools?id=deployment-tools'],
#  ['https://tds.s-anand.net/#/large-language-models?id=large-language-models'],
#  ['https://tds.s-anand.net/#/data-sourcing?id=data-sourcing'],
#  ['https://tds.s-anand.net/#/data-preparation?id=data-preparation'],
#  ['https://tds.s-anand.net/#/data-analysis?id=data-analysis'],
#  ['https://tds.s-anand.net/#/data-visualization?id=data-visualization'],
#  ['https://tds.s-anand.net/#/actor-network-visualization?id=actor-network-visualization'],
#  ['https://tds.s-anand.net/#/github-copilot?id=ai-editor-github-copilot'],
#  ['https://tds.s-anand.net/#/llm?id=key-features'],
#  ['https://tds.s-anand.net/#/google-auth?id=google-authentication-with-fastapi'],
#  ['https://tds.s-anand.net/#/base64-encoding?id=base-64-encoding'],
#  ['https://tds.s-anand.net/#/bbc-weather-api-with-python?id=bbc-weather-location-id-with-python'],
# ...

# %%
len(all_chunks[:69])
# Out:
# 69

# %%
len(all_embeddings[:69])
# Out:
# 69
